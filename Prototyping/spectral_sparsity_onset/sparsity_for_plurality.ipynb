# %% [markdown]
# ## Measuring the spectral sparsity of a song with both single notes and chords

# %%
import librosa
import librosa.display
from pathlib import Path
import sys
sys.path.insert(1, str(Path.cwd().parent.parent))
import matplotlib.pyplot as plt
from tensor_hero.preprocessing.audio import ninos

audio, sr= librosa.load(str(Path.cwd() / 'mediumhall.mp3'))
print(sr)
plt.plot(audio)
# Out:
# C:\Users\ewais\AppData\Local\Programs\Python\Python38\lib\site-packages\librosa\core\audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# 22050

# %%
import sounddevice as sd

sd.play(audio, sr)

# %%
ninos_array, J, hop_len = ninos(audio, sr)
# Out:
# old spec shape: (513, 5882)
# J: 482
# new spec shape: (482, 5882)
# l2_squared shape: (5882,)
# l4 shape: (5882,)

# %%
plt.figure(figsize=(10,10))
plt.subplots(figsize=(10,10))
plt.subplot(2, 1, 1)
plt.plot(audio)
plt.subplot(2, 1, 2)
plt.plot(ninos_array)

# %%
sections = [audio[i*1000:(i+1)*1000] for i in range(audio.shape[0]/1000)]

for sect in sections:
    sd.play(sect)
    time.sleep()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-bf3b63815b1d> in <module>
#       6 for sect in sections:
#       7     sd.play(sect)
# ----> 8     time.sleep(2)
#
# KeyboardInterrupt:
