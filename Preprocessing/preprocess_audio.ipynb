# %% [markdown]
# The purpose of this notebook is to
# - iterate through the unprocessed data
#     - for each song
#         - create tensor of one hot notes
#         - create tensor of audio waveform
#         - place them in \Training Data\Processed

# %%
from pathlib import Path
sys.path.insert(1, str(Path().resolve().parent) + r'\Preprocessing')
import os
from chart_functions import chart2tensor, get_configuration
from audio_functions import music2tensor
from tqdm import tqdm
import numpy as np

unprocessed_data_path = Path(r'X:\Training Data\Unprocessed')
processed_data_path = Path(r'X:\Training Data\Processed')

# %%
def check_multiple_audio_files(fileList):
    # Get audio file list
    num_files = 0
    multiple_files = False
    mp3 = False         # Boolean to determine if songs are in mp3 format
    wav = False
    for track in fileList:
        if track.endswith('.ogg'):
            num_files += 1
        if track.endswith('.mp3'):
            num_files += 1
        if track.endswith('.wav'):
            num_files += 1
    if num_files > 1:
        multiple_files = True
    return multiple_files

def get_audio_file_name(fileList):
    for track in fileList:
        if track.endswith('.ogg') or track.endswith('.mp3') or track.endswith('.wav'):
            return track
    raise NameError('Error: audio file not present')

# %%
wrong_format_charts = []    # Holds paths to charts not in .chart format
multiple_audio_songs = []   # Holds paths to charts with multiple audio files
processed = []              # Holds paths to song folders that were successfully processed
song_size = 0               # Total audio data size, in gigabytes
notes_size = 0              # Total note data size, in gigabytes

i = 0
for dirName, subdirList, fileList in tqdm(os.walk(unprocessed_data_path)):  # Walk through training data directory
    if not fileList:  # If file list is empty
        continue
    track_pack_ = str(Path(dirName).parent).split('\\')[3]
    song_ = str(Path(dirName)).split('\\')[4]
    processed_path = processed_data_path / track_pack_ / song_
    unprocessed_path = unprocessed_data_path / track_pack_ / song_
    processed_song_path = processed_path / 'song.npy'
    processed_notes_path = processed_path / 'notes.npy'

    print('\n\nProcessing {}, {}'.format(track_pack_, song_))
    if processed_notes_path.exists():
        os.remove(processed_notes_path)  # Delete because I accidentally saved the same array hundreds of times lol

    # Skip creating the directory if there is more than one audio file
    if check_multiple_audio_files(fileList):
        multiple_audio_songs.append(unprocessed_song_path)
        print('{}, {} contains multiple audio files, skipping'.format(track_pack_, song_))
        continue
    else:
        audio_file_name = get_audio_file_name(fileList)
        unprocessed_song_path = unprocessed_path / audio_file_name

    # Create note tensor for song
    try:
        note_tensor = np.array(chart2tensor(unprocessed_path / 'notes.chart', print_release_notes = False)).astype(int)
    except:
        print('{}, {} .chart file is in the wrong format, skipping'.format(track_pack_, song_))
        wrong_format_charts.append(unprocessed_song_path)
        continue
    
    # Make folder in 'Processed' if it doesn't already exist
    if not processed_path.exists():
        os.mkdir(processed_path)

    # Check if song has already been processed
    if processed_song_path.exists():
        print('{} audio has already been processed'.format(str(Path(processed_path)).split('\\')[-1]))
        song_size += (processed_song_path.stat().st_size) / 1e9
    else:
        song = music2tensor(unprocessed_song_path)
        np.save(processed_song_path, song)
        song_size += (processed_song_path.stat().st_size) / 1e9
    
    # Check if notes have already been processed
    if processed_notes_path.exists():
        print('{} notes have already been procesed'.format(str(Path(processed_path)).split('\\')[-1]))
        notes_size += (processed_notes_path.stat().st_size) / 1e9
    else:
        np.save(processed_notes_path, note_tensor)
        notes_size += (processed_notes_path.stat().st_size) / 1e9
# Out:
# 10it [00:00, 92.25it/s]
#
# Processing Angevil Hero II, 1. Andy McKee - Ouray
# 1. Andy McKee - Ouray audio has already been processed
#
#
# Processing Angevil Hero II, 1. Joe Satriani - The Forgotten (Part One + Part Two)
# 1. Joe Satriani - The Forgotten (Part One + Part Two) audio has already been processed
#
#
# Processing Angevil Hero II, 1. John 5 - 27 Needles
# 1. John 5 - 27 Needles audio has already been processed
#
#
# Processing Angevil Hero II, 1. Lordi - Mr. Killjoy
# 1. Lordi - Mr. Killjoy audio has already been processed
#
#
# Processing Angevil Hero II, 1. Megadeth - Kick the Chair
# 1. Megadeth - Kick the Chair audio has already been processed
#
#
# Processing Angevil Hero II, 1. Paul Gilbert - 2 Become 1 (Spice Girls Cover)
# 1. Paul Gilbert - 2 Become 1 (Spice Girls Cover) audio has already been processed
#
#
# Processing Angevil Hero II, 1. Protest the Hero - Limb from Limb (with Intro)
# 1. Protest the Hero - Limb from Limb (with Intro) audio has already been processed
#
#
# Processing Angevil Hero II, 1. Protest the Hero - Wretch (with Intro)
# 1. Protest the Hero - Wretch (with Intro) audio has already been processed
#
#
# Processing Angevil Hero II, 1. Scar Symmetry - Dreaming 24_7
# 1. Scar Symmetry - Dreaming 24_7 audio has already been processed
#
#
# Processing Angevil Hero II, 1. Syu - Guitar Demonstration #2
# 1. Syu - Guitar Demonstration #2 audio has already been processed
#
#
# Processing Angevil Hero II, 1. Trivium - To the Rats
# 1. Trivium - To the Rats audio has already been processed
#
#
# Processing Angevil Hero II, 2. Dark Tranquillity - Punish My Heaven
# 2. Dark Tranquillity - Punish My Heaven audio has already been processed
#
#
# Processing Angevil Hero II, 2. Death - Spirit Crusher
# 2. Death - Spirit Crusher audio has already been processed
#
#
# Processing Angevil Hero II, 2. Mastodon - Blood and Thunder
# 2. Mastodon - Blood and Thunder audio has already been processed
#
#
# Processing Angevil Hero II, 2. Megadeth - Chosen Ones
# 2. Megadeth - Chosen Ones audio has already been processed
#
#
# Processing Angevil Hero II, 2. Metalium - Free Forever
# 2. Metalium - Free Forever audio has already been processed
#
#
# 30it [00:00, 87.95it/s]
# 2. Spastic Ink - The Mad Data Race audio has already been processed
#
#
# Processing Angevil Hero II, 2. The Hellecasters - Help I've Fallen (& I Can't Get Up)
# 2. The Hellecasters - Help I've Fallen (& I Can't Get Up) audio has already been processed
#
#
# Processing Angevil Hero II, 2. Venom - Witching Hour
# 2. Venom - Witching Hour audio has already been processed
#
#
# Processing Angevil Hero II, 2. Vision Divine - La Vita Fugge (Chapter VI)
# 2. Vision Divine - La Vita Fugge (Chapter VI) audio has already been processed
#
#
# Processing Angevil Hero II, 2. Warmen - Return of Salieri
# 2. Warmen - Return of Salieri audio has already been processed
#
#
# Processing Angevil Hero II, 2. Yngwie J. Malmsteen's Rising Force - Blitzkrieg
# 2. Yngwie J. Malmsteen's Rising Force - Blitzkrieg audio has already been processed
#
#
# Processing Angevil Hero II, 3. Dio - Rainbow in the Dark
# 3. Dio - Rainbow in the Dark audio has already been processed
#
#
# Processing Angevil Hero II, 3. Immortal - At the Heart of Winter
# 3. Immortal - At the Heart of Winter audio has already been processed
#
#
# Processing Angevil Hero II, 3. Impellitteri - Race Into the Light
# 3. Impellitteri - Race Into the Light audio has already been processed
#
#
# Processing Angevil Hero II, 3. Luca Turilli - Black Dragon
# 3. Luca Turilli - Black Dragon audio has already been processed
#
#
# Processing Angevil Hero II, 3. Michael Romeo - Paganini - Concerto in B Minor
# 3. Michael Romeo - Paganini - Concerto in B Minor audio has already been processed
#
#
# Processing Angevil Hero II, 3. Mötley Crüe - Dr. Feelgood
# 3. Mötley Crüe - Dr. Feelgood audio has already been processed
#
#
# Processing Angevil Hero II, 3. Necrophagist - Stabwound
# 3. Necrophagist - Stabwound audio has already been processed
#
#
# Processing Angevil Hero II, 3. Nevermore - The Psalm of Lydia
# 3. Nevermore - The Psalm of Lydia audio has already been processed
#
#
# Processing Angevil Hero II, 3. Steve Vai - Erotic Nightmares
# 3. Steve Vai - Erotic Nightmares audio has already been processed
#
#
# Processing Angevil Hero II, 3. Trivium - Insurrection
# 3. Trivium - Insurrection audio has already been processed
# 48it [00:00, 83.45it/s]
#
# Processing Angevil Hero II, 3. Yngwie J. Malmsteen's Rising Force - Asylum
# 3. Yngwie J. Malmsteen's Rising Force - Asylum audio has already been processed
#
#
# Processing Angevil Hero II, 4. Alter Bridge - Ahavo Rabo Taco Salad
# 4. Alter Bridge - Ahavo Rabo Taco Salad audio has already been processed
#
#
# Processing Angevil Hero II, 4. Amon Amarth - Asator
# 4. Amon Amarth - Asator audio has already been processed
#
#
# Processing Angevil Hero II, 4. Andromeda - Morphing Into Nothing
# 4. Andromeda - Morphing Into Nothing audio has already been processed
#
#
# Processing Angevil Hero II, 4. Blind Guardian - Banish from Sanctuary
# 4. Blind Guardian - Banish from Sanctuary audio has already been processed
#
#
# Processing Angevil Hero II, 4. Divine Heresy - Failed Creation
# 4. Divine Heresy - Failed Creation audio has already been processed
#
#
# Processing Angevil Hero II, 4. Gentaro Satomura - Attack of the Aliens
# 4. Gentaro Satomura - Attack of the Aliens audio has already been processed
#
#
# Processing Angevil Hero II, 4. Kid Rock - Cowboy
# 4. Kid Rock - Cowboy audio has already been processed
#
#
# Processing Angevil Hero II, 4. Megadeth - I Thought I Knew it All
# 4. Megadeth - I Thought I Knew it All audio has already been processed
#
#
# Processing Angevil Hero II, 4. Paul Gilbert - I Feel Love (Donna Summer Cover)
# 4. Paul Gilbert - I Feel Love (Donna Summer Cover) audio has already been processed
#
#
# Processing Angevil Hero II, 4. Stratovarius - Fire Dance
# 4. Stratovarius - Fire Dance audio has already been processed
#
#
# Processing Angevil Hero II, 4. Warmen - Beyond Abilities
# 4. Warmen - Beyond Abilities audio has already been processed
#
#
# Processing Angevil Hero II, 5. Dying Fetus - Homicidal Retribution
# 5. Dying Fetus - Homicidal Retribution audio has already been processed
#
#
# Processing Angevil Hero II, 5. Eric Sardinas - Down in the Bottom
# 5. Eric Sardinas - Down in the Bottom audio has already been processed
#
#
# Processing Angevil Hero II, 5. Exodus - Funeral Hymn
# 57it [00:00, 79.98it/s]
#
#
# Processing Angevil Hero II, 5. Joe Satriani - Big Bad Moon
# 5. Joe Satriani - Big Bad Moon audio has already been processed
#
#
# Processing Angevil Hero II, 5. Lostprophets - Kobrakai
# 5. Lostprophets - Kobrakai audio has already been processed
#
#
# Processing Angevil Hero II, 5. Loudness - You Shook Me
# 5. Loudness - You Shook Me audio has already been processed
#
#
# Processing Angevil Hero II, 5. Megadeth - Back in the Day
# 5. Megadeth - Back in the Day audio has already been processed
#
#
# Processing Angevil Hero II, 5. Megadeth - Blood of Heroes
# 5. Megadeth - Blood of Heroes audio has already been processed
#
#
# Processing Angevil Hero II, 5. SIAM SHADE - Triptych
# 5. SIAM SHADE - Triptych audio has already been processed
#
#
# Processing Angevil Hero II, 5. Sinergy - The Warrior Princess
# 5. Sinergy - The Warrior Princess audio has already been processed
#
#
# Processing Angevil Hero II, 5. Spastic Ink - Multi-Masking
# 5. Spastic Ink - Multi-Masking audio has already been processed
#
#
# Processing Angevil Hero II, 6. 3 Inches of Blood - Axes of Evil
# 6. 3 Inches of Blood - Axes of Evil audio has already been processed
#
#
# Processing Angevil Hero II, 6. All Shall Perish - Never...Again
# 6. All Shall Perish - Never...Again audio has already been processed
#
#
# Processing Angevil Hero II, 6. Avenged Sevenfold - Dancing Dead
# 6. Avenged Sevenfold - Dancing Dead audio has already been processed
# 76it [00:00, 79.13it/s]
#
# Processing Angevil Hero II, 6. Coroner - Nosferatu
# 6. Coroner - Nosferatu audio has already been processed
#
#
# Processing Angevil Hero II, 6. Dethklok - Murdertrain a Comin'
# 6. Dethklok - Murdertrain a Comin' audio has already been processed
#
#
# Processing Angevil Hero II, 6. Dir En Grey - Agitated Screams of Maggots
# 6. Dir En Grey - Agitated Screams of Maggots audio has already been processed
#
#
# Processing Angevil Hero II, 6. Jason Becker - Paganini's 5th Caprice
# 6. Jason Becker - Paganini's 5th Caprice audio has already been processed
#
#
# Processing Angevil Hero II, 6. John Petrucci - Animate-Inanimate
# 6. John Petrucci - Animate-Inanimate audio has already been processed
#
#
# Processing Angevil Hero II, 6. Megadeth - Something That I'm Not
# 6. Megadeth - Something That I'm Not audio has already been processed
#
#
# Processing Angevil Hero II, 6. Norther - Nothing Left
# 6. Norther - Nothing Left audio has already been processed
#
#
# Processing Angevil Hero II, 6. Sinergy - I Spit on Your Grave
# 6. Sinergy - I Spit on Your Grave audio has already been processed
#
#
# Processing Angevil Hero II, 7. The Hellecasters - Orange Blossom Special
# 7. The Hellecasters - Orange Blossom Special audio has already been processed
#
#
# Processing Anti Hero, 01. Brave This Storm (Miscellany)
# 01. Brave This Storm (Miscellany) audio has already been processed
#
#
# Processing Anti Hero, 01. Broken Soul (Chezy)
# 01. Broken Soul (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 01. Human Disaster (Chezy)
# 01. Human Disaster (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 01. The Primeval Dark (DigitalSquirrel)
# 01. The Primeval Dark (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, 02. Cauterizer (Chezy)
# 02. Cauterizer (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 02. Sweetest Poison (Chezy)
# 02. Sweetest Poison (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 02. While We Sleep (Digitalsquirrel)
# 02. While We Sleep (Digitalsquirrel) audio has already been processed
#
#
# Processing Anti Hero, 03. Pseudo Self (Chezy)
# 03. Pseudo Self (Chezy) audio has already been processed
# 85it [00:01, 80.79it/s]
#
# Processing Anti Hero, 03. Revelation (DigitalSquirrel)
# 03. Revelation (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, 03. Send Help (Chezy)
# 03. Send Help (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 03. Strife (Miscellany)
# 03. Strife (Miscellany) audio has already been processed
#
#
# Processing Anti Hero, 04. Black Heart Rebellion (Digitalsquirrel)
# 04. Black Heart Rebellion (Digitalsquirrel) audio has already been processed
#
#
# Processing Anti Hero, 04. Defenseless (Chezy)
# 04. Defenseless (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 04. Holy Walls of the Vatican (Chezy)
# 04. Holy Walls of the Vatican (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 05. Lose To Night (DigitalSquirrel)
# 05. Lose To Night (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, 05. The Void (Chezy)
# 05. The Void (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 05. VVorld Demise (Chezy)
# 05. VVorld Demise (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 06. At the End of This War (Miscellany)
# 06. At the End of This War (Miscellany) audio has already been processed
#
#
# Processing Anti Hero, 06. Collapsing Words (DigitalSquirrel)
# 06. Collapsing Words (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, 06. Inner Demons (Chezy)
# 06. Inner Demons (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 06. Nailgun (Chezy)
# 06. Nailgun (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 07. Decamilli (Chezy)
# 07. Decamilli (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 07. Graveyard Shift (Chezy)
# 07. Graveyard Shift (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 07. The River (DigitalSquirrel)
# 07. The River (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, 08. Bridgepainter (Chezy)
# 105it [00:01, 88.39it/s]
#
#
# Processing Anti Hero, 08. Ephemeral (Digitalsquirrel)
# 08. Ephemeral (Digitalsquirrel) audio has already been processed
#
#
# Processing Anti Hero, 08. Nooses (Chezy)
# 08. Nooses (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 08. Villainy Thrives (Miscellany)
# 08. Villainy Thrives (Miscellany) audio has already been processed
#
#
# Processing Anti Hero, 09. Incineration - The Broken World (Miscellany)
# 09. Incineration - The Broken World (Miscellany) audio has already been processed
#
#
# Processing Anti Hero, 09. The Promethean Song (DigitalSquirrel)
# 09. The Promethean Song (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, 09. The Tightrope (Chezy)
# 09. The Tightrope (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 09. Whale Shark (Chezy)
# 09. Whale Shark (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 09_The Tempest (Chemfinal)
# 09_The Tempest (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero, 1 -  . _ _ _ _
# 1 -  . _ _ _ _ audio has already been processed
#
#
# Processing Anti Hero, 10. Delusionalisphere (Chezy)
# 10. Delusionalisphere (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 10. Illuminate (Chezy)
# 10. Illuminate (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 10. Shadows of the Dying Sun (DigitalSquirrel)
# 10. Shadows of the Dying Sun (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, 10. Wake (The End Is Nigh) (Miscellany)
# 10. Wake (The End Is Nigh) (Miscellany) audio has already been processed
#
#
# Processing Anti Hero, 11. Bloodwork (Chezy)
# 11. Bloodwork (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 11. Observer (Chezy)
# 11. Observer (Chezy) audio has already been processed
#
#
# Processing Anti Hero, 11. Out to the Sea (Insomnium)
# 11. Out to the Sea (Insomnium) audio has already been processed
#
#
# Processing Anti Hero, 12. As I Am Exploding (Miscellany)
# 124it [00:01, 86.84it/s]
#
#
# Processing Anti Hero, 13_I Can Never Go Home (Reprise) (Chemfinal)
# 13_I Can Never Go Home (Reprise) (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero, 14. Losing My Religion (R.E.M Cover) (Miscellany)
# 14. Losing My Religion (R.E.M Cover) (Miscellany) audio has already been processed
#
#
# Processing Anti Hero, 2 - . . _ _ _
# 2 - . . _ _ _ audio has already been processed
#
#
# Processing Anti Hero, 3 - . . . _ _ (Ft. Fabrizio Leo)
# 3 - . . . _ _ (Ft. Fabrizio Leo) audio has already been processed
#
#
# Processing Anti Hero, 4 - . . . . _
# 4 - . . . . _ audio has already been processed
#
#
# Processing Anti Hero, 5 -
# 5 - audio has already been processed
#
#
# Processing Anti Hero, A Night In The Abyss - Deicide (Chezy)
# A Night In The Abyss - Deicide (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Abiogenesis - Visualize (Chezy)
# Abiogenesis - Visualize (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Aborted - Retrogore (DeathofTeyolia)
# Aborted - Retrogore (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Akira Sora - Columpio (DigitalSquirrel)
# Akira Sora - Columpio (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, All Shall Perish - Procession of Ashes (DeathofTeyolia)
# All Shall Perish - Procession of Ashes (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Allegaeon - Threshold of Perception (DeathofTeyolia)
# Allegaeon - Threshold of Perception (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Alterbeast - Ancient's Retribution (deathofteyolia)
# Alterbeast - Ancient's Retribution (deathofteyolia) audio has already been processed
#
#
# Processing Anti Hero, Alterbeast - Throne of Maggots (ChemFinal)
# Alterbeast - Throne of Maggots (ChemFinal) audio has already been processed
#
#
# Processing Anti Hero, And Hell Followed With - One Of The Swarm (DeathofTeyolia)
# And Hell Followed With - One Of The Swarm (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, AngelMaker - Abysmal (DeathofTeyolia)
# AngelMaker - Abysmal (DeathofTeyolia) audio has already been processed
# 142it [00:01, 85.22it/s]
#
# Processing Anti Hero, AngelMaker - Leech (DeathofTeyolia)
# AngelMaker - Leech (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Animals as Leaders - The Glass Bridge (Dillski)
# Animals as Leaders - The Glass Bridge (Dillski) audio has already been processed
#
#
# Processing Anti Hero, Anterior - Seraph (DeathofTeyolia)
# Anterior - Seraph (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Area 11 - Dream and Reality (DigitalSquirrel)
# Area 11 - Dream and Reality (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, Artificial Language - Mazes (DeathofTeyolia)
# Artificial Language - Mazes (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, As Blood Runs Black - Resist (DeathofTeyolia)
# As Blood Runs Black - Resist (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, As I Lay Dying - Forsaken (DeathofTeyolia)
# As I Lay Dying - Forsaken (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, As I Lay Dying - The Plague (DeathofTeyolia)
# As I Lay Dying - The Plague (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, At the Gates - Slaughter of the Soul (DeathofTeyolia)
# At the Gates - Slaughter of the Soul (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, At the Throne of Judgment - Mariner's Cutlass (DeathofTeyolia)
# At the Throne of Judgment - Mariner's Cutlass (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Atlantis Chronicles - The Odysseus (DeathofTeyolia)
# Atlantis Chronicles - The Odysseus (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Audioslave - Exploder (Chezy)
# Audioslave - Exploder (Chezy) audio has already been processed
#
#
# Processing Anti Hero, August Burns Red - Dangerous (DeathofTeyolia)
# August Burns Red - Dangerous (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Beneath The Sky - 7861 (DeathofTeyolia)
# Beneath The Sky - 7861 (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Beyond Creation - Omnipresent Perception (DeathofTeyolia)
# Beyond Creation - Omnipresent Perception (DeathofTeyolia) audio has already been processed
# 151it [00:01, 82.15it/s]
#
# Processing Anti Hero, Billy Ray Cyrus - I Want My Mullet Back (Chezy)
# Billy Ray Cyrus - I Want My Mullet Back (Chezy) audio has already been processed
#
#
# Processing Anti Hero, blink-182 - Bottom Of The Ocean (Chezy)
# blink-182 - Bottom Of The Ocean (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Bloodshot Dawn - Inadequacy (DeathofTeyolia)
# Bloodshot Dawn - Inadequacy (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Bloodshot Dawn - The Image Faded (DigitalSquirrel)
# Bloodshot Dawn - The Image Faded (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, Brand New - Degausser (Chezy)
# Brand New - Degausser (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Brandon Ellis - No Escape (Chezy)
# Brandon Ellis - No Escape (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Bullet For My Valentine - 4 Words (To Choke Upon) (DeathofTeyolia)
# Bullet For My Valentine - 4 Words (To Choke Upon) (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Cattle Decapitation - Pacific Grim (DeathofTeyolia)
# Cattle Decapitation - Pacific Grim (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Chimaira - Resurrection (Digitalsquirrel)
# Chimaira - Resurrection (Digitalsquirrel) audio has already been processed
#
#
# Processing Anti Hero, Conducting from the Grave - Eternally Gutted
# Conducting from the Grave - Eternally Gutted audio has already been processed
#
#
# Processing Anti Hero, Conducting from the Grave - What Monsters We Have Become 1 & 2 (DeathofTeyolia)
# Conducting from the Grave - What Monsters We Have Become 1 & 2 (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Counterparts - Drown (Chezy)
# Counterparts - Drown (Chezy) audio has already been processed
#
#
# Processing Anti Hero, David Maxim Micic - Rise and Shine (ft. Jakub Zytechi) (Dillski)
# David Maxim Micic - Rise and Shine (ft. Jakub Zytechi) (Dillski) audio has already been processed
#
#
# Processing Anti Hero, Dawn of Disease - Through Nameless Ages (DeathofTeyolia)
# 171it [00:02, 83.40it/s]
#
#
# Processing Anti Hero, Decrepit Birth - (A Departure Of The Sun) Ignite The Tesla Coil (DeathofTeyolia)
# Decrepit Birth - (A Departure Of The Sun) Ignite The Tesla Coil (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Depths of Hatred - Ministry of Deceit (DeathofTeyolia)
# Depths of Hatred - Ministry of Deceit (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Desolace - Green (DeathofTeyolia)
# Desolace - Green (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Destiny Potato - Blue Sun (Dillski)
# Destiny Potato - Blue Sun (Dillski) audio has already been processed
#
#
# Processing Anti Hero, Destrage - Collateral Pleasure (DeathofTeyolia)
# Destrage - Collateral Pleasure (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Die From Sorrow - Sea of Rebirth (DigitalSquirrel)
# Die From Sorrow - Sea of Rebirth (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, DigitalSquirrel - You're Out (DigitalSquirrel)
# DigitalSquirrel - You're Out (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, Disfigured Elegance - The Last Disease (DeathofTeyolia)
# Disfigured Elegance - The Last Disease (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Don Broco - Actors (Chezy)
# Don Broco - Actors (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Erra - Hybrid Earth (DeathofTeyolia)
# Erra - Hybrid Earth (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Fallujah - Cerebral Hybridization (DeathofTeyolia)
# Fallujah - Cerebral Hybridization (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, FamilyJules - Super Mario Bros. Theme (ft. John Petrucci) (Dillski)
# FamilyJules - Super Mario Bros. Theme (ft. John Petrucci) (Dillski) audio has already been processed
#
#
# Processing Anti Hero, Fire Within - Artificial Perception (DigitalSquirrel)
# Fire Within - Artificial Perception (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, Fit for an Autopsy - Black Mammoth (DeathofTeyolia)
# Fit for an Autopsy - Black Mammoth (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Fleshgod Apocalypse - Conspiracy of Silence (Chemfinal)
# Fleshgod Apocalypse - Conspiracy of Silence (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero, From the Shallows - Battle Axe (DeathofTeyolia)
# From the Shallows - Battle Axe (DeathofTeyolia) audio has already been processed
# 180it [00:02, 81.45it/s]
#
# Processing Anti Hero, Galneryus - Face to the Real (Chemfinal)
# Galneryus - Face to the Real (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero, Galneryus - Holding the Broken Wings (Chemfinal)
# Galneryus - Holding the Broken Wings (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero, Gravemind - Anaesthesia (DeathofTeyolia)
# Gravemind - Anaesthesia (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Hail the Sun - Will They Blame Me If You Go Disappearing (Chezy)
# Hail the Sun - Will They Blame Me If You Go Disappearing (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Hechizeros Band - El Sonidito (Chezy)
# Hechizeros Band - El Sonidito (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Hellborg, Lane, Sipe - Rice with the Angels (Live) (Chemfinal)
# Hellborg, Lane, Sipe - Rice with the Angels (Live) (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero, Hellions - Nightliner Rhapsody (Chezy)
# Hellions - Nightliner Rhapsody (Chezy) audio has already been processed
#
#
# Processing Anti Hero, i built the sky - Stratiformis (ft. Jake Howsam Lowe) (Dillski)
# i built the sky - Stratiformis (ft. Jake Howsam Lowe) (Dillski) audio has already been processed
#
#
# Processing Anti Hero, Ignominious Incarceration - The Saviour (DeathofTeyolia)
# Ignominious Incarceration - The Saviour (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Impending Doom - Anything Goes (Chezy)
# Impending Doom - Anything Goes (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Inferi - Marching Through The Flames Of Tyranny (DeathofTeyolia)
# Inferi - Marching Through The Flames Of Tyranny (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Intervals - Belvedere (DeathofTeyolia)
# Intervals - Belvedere (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Jason Becker - Serrana (Chemfinal)
# Jason Becker - Serrana (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero, Jason Richardson - Fragments (feat. Lukas Magyar & Mark Holcomb) (DeathofTeyolia)
# Jason Richardson - Fragments (feat. Lukas Magyar & Mark Holcomb) (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Job For A Cowboy - The Synthetic Sea (DeathofTeyolia)
# Job For A Cowboy - The Synthetic Sea (DeathofTeyolia) audio has already been processed
# 198it [00:02, 82.46it/s]
#
# Processing Anti Hero, Kero Kero Bonito - Flamingo (Chezy)
# Kero Kero Bonito - Flamingo (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Killswitch Engage - Numbered Days (DeathofTeyolia)
# Killswitch Engage - Numbered Days (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Limp Bizkit - The Truth (m9)
# Limp Bizkit - The Truth (m9) audio has already been processed
#
#
# Processing Anti Hero, Little Tybee - Golden Delilah (ChemFinal)
# Little Tybee - Golden Delilah (ChemFinal) audio has already been processed
#
#
# Processing Anti Hero, Lorna Shore - Flesh Coffin (DeathofTeyolia)
# Lorna Shore - Flesh Coffin (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Luck Wont Save You - Alone In Reverie (DeathofTeyolia)
# Luck Wont Save You - Alone In Reverie (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Machinae Supremacy - All of My Angels (DigitalSquirrel)
# Machinae Supremacy - All of My Angels (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, Miss May I - Apologies Are for the Weak (DeathofTeyolia)
# Miss May I - Apologies Are for the Weak (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Necrophagist - Fermented Offal Discharge (Chezy)
# Necrophagist - Fermented Offal Discharge (Chezy) audio has already been processed
#
#
# Processing Anti Hero, No Bragging Rights - And They Threatened Us With Fire (Chezy) [ENCORE]
# No Bragging Rights - And They Threatened Us With Fire (Chezy) [ENCORE] audio has already been processed
#
#
# Processing Anti Hero, Noel Pix - Die Legende (m9)
# Noel Pix - Die Legende (m9) audio has already been processed
#
#
# Processing Anti Hero, Oath to Order - White Widow (DeathofTeyolia)
# Oath to Order - White Widow (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Oathbreaker - Second Son Of R (Chezy)
# Oathbreaker - Second Son Of R (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Parasite Inc. - Fire the Machines + Back For War (DeathofTeyolia)
# Parasite Inc. - Fire the Machines + Back For War (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Parkway Drive - A Deathless Song (Chezy)
# Parkway Drive - A Deathless Song (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Parkway Drive - Gimme A D (DeathofTeyolia)
# 216it [00:02, 81.41it/s]
#
#
# Processing Anti Hero, Persefone - Spirals Within Thy Being (Chemfinal)
# Persefone - Spirals Within Thy Being (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero, Phinehas - Hell Below (DeathofTeyolia)
# Phinehas - Hell Below (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Polaris - Lucid (Chezy)
# Polaris - Lucid (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Pronostic - Becik (DeathofTeyolia)
# Pronostic - Becik (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Rings of Saturn - Desolate Paradise (DigitalSquirrel)
# Rings of Saturn - Desolate Paradise (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, Rings of Saturn - Immemorial Essence (DeathofTeyolia)
# Rings of Saturn - Immemorial Essence (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Rings of Saturn - Margidda (DigitalSquirrel)
# Rings of Saturn - Margidda (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, Rolo Tomassi - Stage Knives (Chezy)
# Rolo Tomassi - Stage Knives (Chezy) audio has already been processed
#
#
# Processing Anti Hero, Scar Symmetry - The Path of Least Resistance (DeathofTeyolia)
# Scar Symmetry - The Path of Least Resistance (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Sentinels - Consequent Aversion (DeathofTeyolia)
# Sentinels - Consequent Aversion (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Shadows Fall - The Unknown (DeathofTeyolia)
# Shadows Fall - The Unknown (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Shokran - The Blood & Creatures from the Mud (DeathofTeyolia)
# Shokran - The Blood & Creatures from the Mud (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Shores Of Elysium - Mindsculpt (DeathofTeyolia)
# Shores Of Elysium - Mindsculpt (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Shylmagoghnar - I Am the Abyss (DigitalSquirrel)
# Shylmagoghnar - I Am the Abyss (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, Slaughter to Prevail - Crowned & Conquered (feat. Lucas Mann)
# Slaughter to Prevail - Crowned & Conquered (feat. Lucas Mann) audio has already been processed
# 235it [00:02, 86.00it/s]
#
# Processing Anti Hero, Spite - Kill or Be Killed (DeathofTeyolia)
# Spite - Kill or Be Killed (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Starset - Bringing It Down (Digitalsquirrel)
# Starset - Bringing It Down (Digitalsquirrel) audio has already been processed
#
#
# Processing Anti Hero, Starset - Into The Unknown (DigitalSquirrel)
# Starset - Into The Unknown (DigitalSquirrel) audio has already been processed
#
#
# Processing Anti Hero, T-Square - Truth (Chemfinal)
# T-Square - Truth (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero, The Acacia Strain - Tactical Nuke (Chezy)
# The Acacia Strain - Tactical Nuke (Chezy) audio has already been processed
#
#
# Processing Anti Hero, The Air I Breathe - Take This to Heart (DeathofTeyolia)
# The Air I Breathe - Take This to Heart (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, The Black Dahlia Murder - Deathmask Divine (Chezy)
# The Black Dahlia Murder - Deathmask Divine (Chezy) audio has already been processed
#
#
# Processing Anti Hero, The Black Dahlia Murder - Receipt (DeathofTeyolia)
# The Black Dahlia Murder - Receipt (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, The Contortionist - Oscillator (DeathofTeyolia)
# The Contortionist - Oscillator (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, The Raven Autarchy - The Obscene Deliverance (DeathofTeyolia)
# The Raven Autarchy - The Obscene Deliverance (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, The Zenith Passage - Deus Deceptor (DeathofTeyolia)
# The Zenith Passage - Deus Deceptor (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Throne Of The Beheaded - Reformation (feat. Aleksander Abdulov) (DeathofTeyolia)
# Throne Of The Beheaded - Reformation (feat. Aleksander Abdulov) (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Unearth - Eyes of Black (DeathofTeyolia)
# Unearth - Eyes of Black (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Unearth - The Swarm (DeathofTeyolia)
# Unearth - The Swarm (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Until We Die - As Fear Became Reality (DeathofTeyolia)
# Until We Die - As Fear Became Reality (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Vale Of Pnath - Heart Of Darkness (DeathofTeyolia)
# Vale Of Pnath - Heart Of Darkness (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Vektor - Dying World (Chemfinal)
# Vektor - Dying World (Chemfinal) audio has already been processed
# 246it [00:02, 92.56it/s]
#
# Processing Anti Hero, Virulent Depravity - Your Demise (DeathofTeyolia)
# Virulent Depravity - Your Demise (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Vitalij Kuprij - Opus 1 (Theme by Paganini) (Chemfinal)
# Vitalij Kuprij - Opus 1 (Theme by Paganini) (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero, Wage War - Witness (DeathofTeyolia)
# Wage War - Witness (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Within the Ruins - Clockwork (DeathofTeyolia)
# Within the Ruins - Clockwork (DeathofTeyolia) audio has already been processed
#
#
# Processing Anti Hero, Within the Ruins - Feast or Famine (Chezy)
# Within the Ruins - Feast or Famine (Chezy) audio has already been processed
#
#
# Processing Anti Hero 2, 50 Cent - Ayo Technology (feat. Justin Timberlake) (Siavash)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\50 Cent - Ayo Technology (feat. Justin Timberlake) (Siavash)\notes.chart is not in .chart format
# Anti Hero 2, 50 Cent - Ayo Technology (feat. Justin Timberlake) (Siavash) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, ABBA - Gimme! Gimme! Gimme! (Raspberriel)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\ABBA - Gimme! Gimme! Gimme! (Raspberriel)\notes.chart is not in .chart format
# Anti Hero 2, ABBA - Gimme! Gimme! Gimme! (Raspberriel) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Adam Neely - 7 11 (Paturages)
# Adam Neely - 7 11 (Paturages) audio has already been processed
#
#
# Processing Anti Hero 2, Adam Nitti - Antisocialmedia (JoeyD)
# Adam Nitti - Antisocialmedia (JoeyD) audio has already been processed
#
#
# Processing Anti Hero 2, AFI - Get Dark (Chezy)
# AFI - Get Dark (Chezy) audio has already been processed
#
#
# Processing Anti Hero 2, Afterglow - Lost One no Goukoku (Neru cover) (Raspberriel)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Afterglow - Lost One no Goukoku (Neru cover) (Raspberriel)\notes.chart is not in .chart format
# Anti Hero 2, Afterglow - Lost One no Goukoku (Neru cover) (Raspberriel) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Alhambra - Alhambra Solo Medley (Chemfinal)
# Alhambra - Alhambra Solo Medley (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero 2, Alhambra - Missing You (Chemfinal)
# Alhambra - Missing You (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero 2, Allegaeon - 1.618 (Miscellany)
# Allegaeon - 1.618 (Miscellany) audio has already been processed
#
#
# Processing Anti Hero 2, Allegaeon - Apoptosis (Miscellany)
# 265it [00:03, 81.91it/s]Allegaeon - Apoptosis (Miscellany) audio has already been processed
#
#
# Processing Anti Hero 2, Alter Bridge - Isolation (Jaded)
# Alter Bridge - Isolation (Jaded) audio has already been processed
#
#
# Processing Anti Hero 2, Andy Timmons - Carpe Diem (Arctan)
# Andy Timmons - Carpe Diem (Arctan) audio has already been processed
#
#
# Processing Anti Hero 2, Andy Timmons - Farmer Sez (Arctan)
# Andy Timmons - Farmer Sez (Arctan) audio has already been processed
#
#
# Processing Anti Hero 2, Angel Vivaldi - Acid Reign (Dillski)
# Angel Vivaldi - Acid Reign (Dillski) audio has already been processed
#
#
# Processing Anti Hero 2, Angel Vivaldi - Synapse Solo Medley (Dillski, Siavash, CyclopsDragon)
# Angel Vivaldi - Synapse Solo Medley (Dillski, Siavash, CyclopsDragon) audio has already been processed
#
#
# Processing Anti Hero 2, Animals as Leaders - Arithmophobia (XEntombmentX)
# Animals as Leaders - Arithmophobia (XEntombmentX) audio has already been processed
#
#
# Processing Anti Hero 2, Anthrax - Subjugator (ThundahK)
# Anthrax - Subjugator (ThundahK) audio has already been processed
#
#
# Processing Anti Hero 2, Anubis Gate - Desiderio Omnibus (Supahfast198)
# Anubis Gate - Desiderio Omnibus (Supahfast198) audio has already been processed
#
#
# Processing Anti Hero 2, Apocalyptica - Path (Mintorment)
# Apocalyptica - Path (Mintorment) audio has already been processed
#
#
# Processing Anti Hero 2, Aquellex - Wanderflux (Raspberriel)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Aquellex - Wanderflux (Raspberriel)\notes.chart is not in .chart format
# Anti Hero 2, Aquellex - Wanderflux (Raspberriel) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Arch Echo - 01. Daybreak (gaebpls)
# Arch Echo - 01. Daybreak (gaebpls) audio has already been processed
#
#
# Processing Anti Hero 2, Arch Echo - 02. Immediate Results (gaebpls)
# Arch Echo - 02. Immediate Results (gaebpls) audio has already been processed
#
#
# Processing Anti Hero 2, Arch Echo - 03. Stella (gaebpls)
# Arch Echo - 03. Stella (gaebpls) audio has already been processed
#
#
# Processing Anti Hero 2, Arch Echo - 04. Aurora (gaebpls)
# Arch Echo - 04. Aurora (gaebpls) audio has already been processed
#
#
# Processing Anti Hero 2, Arch Echo - 05. Mukduk (gaebpls)
# Arch Echo - 05. Mukduk (gaebpls) audio has already been processed
#
#
# Processing Anti Hero 2, Arch Echo - 06. Tempest (gaebpls)
# 274it [00:03, 73.45it/s]
#
#
# Processing Anti Hero 2, Arch Echo - 07. Bocksuvfun (gaebpls)
# Arch Echo - 07. Bocksuvfun (gaebpls) audio has already been processed
#
#
# Processing Anti Hero 2, Arch Echo - 08. Iris (gaebpls)
# Arch Echo - 08. Iris (gaebpls) audio has already been processed
#
#
# Processing Anti Hero 2, Arch Echo - You Won't Believe This Solo Medley (gaebpls, CyclopsDragon)
# Arch Echo - You Won't Believe This Solo Medley (gaebpls, CyclopsDragon) audio has already been processed
#
#
# Processing Anti Hero 2, Arch Enemy - Vultures (Sygenysis)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Arch Enemy - Vultures (Sygenysis)\notes.chart is not in .chart format
# Anti Hero 2, Arch Enemy - Vultures (Sygenysis) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Architects - 01. Death Is Not Defeat (XEntombmentX)
# Architects - 01. Death Is Not Defeat (XEntombmentX) audio has already been processed
#
#
# Processing Anti Hero 2, Architects - 02. Hereafter (Chezy)
# Architects - 02. Hereafter (Chezy) audio has already been processed
#
#
# Processing Anti Hero 2, Architects - 03. Mortal After All (XEntombmentX)
# Architects - 03. Mortal After All (XEntombmentX) audio has already been processed
#
#
# Processing Anti Hero 2, Architects - 04. Holy Hell (Miscellany)
# Architects - 04. Holy Hell (Miscellany) audio has already been processed
#
#
# Processing Anti Hero 2, Architects - 05. Damnation (Miscellany)
# Architects - 05. Damnation (Miscellany) audio has already been processed
#
#
# Processing Anti Hero 2, Architects - 06. Royal Beggars (XEntombmentX)
# Architects - 06. Royal Beggars (XEntombmentX) audio has already been processed
#
#
# Processing Anti Hero 2, Architects - 07. Modern Misery (XEntombmentX)
# Architects - 07. Modern Misery (XEntombmentX) audio has already been processed
#
#
# Processing Anti Hero 2, Architects - 08. Dying to Heal (Chezy)
# Architects - 08. Dying to Heal (Chezy) audio has already been processed
#
#
# Processing Anti Hero 2, Architects - 09. The Seventh Circle (Miscellany)
# Architects - 09. The Seventh Circle (Miscellany) audio has already been processed
# 298it [00:03, 92.38it/s]
#
# Processing Anti Hero 2, Architects - 10. Doomsday (Miscellany)
# Architects - 10. Doomsday (Miscellany) audio has already been processed
#
#
# Processing Anti Hero 2, Architects - 11. A Wasted Hymn (Chezy)
# Architects - 11. A Wasted Hymn (Chezy) audio has already been processed
#
#
# Processing Anti Hero 2, Architects - Holy Hell Riff Medley (XEntombmentX, Chezy, Miscellany)
# Architects - Holy Hell Riff Medley (XEntombmentX, Chezy, Miscellany) audio has already been processed
#
#
# Processing Anti Hero 2, ArchWk - Red Shift (ArchWk)
# ArchWk - Red Shift (ArchWk) audio has already been processed
#
#
# Processing Anti Hero 2, Ark Storm - Play for You (Sygenysis)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Ark Storm - Play for You (Sygenysis)\notes.chart is not in .chart format
# Anti Hero 2, Ark Storm - Play for You (Sygenysis) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Art Tatum - Tiger Rag (Arctan)
# Art Tatum - Tiger Rag (Arctan) audio has already been processed
#
#
# Processing Anti Hero 2, Avatar - Glory to Our King Legend of the King (Hellrock120)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Avatar - Glory to Our King Legend of the King (Hellrock120)\notes.chart is not in .chart format
# Anti Hero 2, Avatar - Glory to Our King Legend of the King (Hellrock120) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Avenged Sevenfold - Second Heartbeat (XEntombmentX)
# Avenged Sevenfold - Second Heartbeat (XEntombmentX) audio has already been processed
#
#
# Processing Anti Hero 2, Bad Religion - I Want to Conquer the World (Siavash)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Bad Religion - I Want to Conquer the World (Siavash)\notes.chart is not in .chart format
# Anti Hero 2, Bad Religion - I Want to Conquer the World (Siavash) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Baroness - A Horse Called Golgotha (Sygenysis)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Baroness - A Horse Called Golgotha (Sygenysis)\notes.chart is not in .chart format
# Anti Hero 2, Baroness - A Horse Called Golgotha (Sygenysis) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Bayside - Rumspringa (Return to Heartbreak Road) (Chezy)
# Bayside - Rumspringa (Return to Heartbreak Road) (Chezy) audio has already been processed
#
#
# Processing Anti Hero 2, Beartooth - Used and Abused (Chezy)
# Beartooth - Used and Abused (Chezy) audio has already been processed
#
#
# Processing Anti Hero 2, Ben Folds Five - One Angry Dwarf and 200 Solemn Faces (Jaded)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Ben Folds Five - One Angry Dwarf and 200 Solemn Faces (Jaded)\notes.chart is not in .chart format
# Anti Hero 2, Ben Folds Five - One Angry Dwarf and 200 Solemn Faces (Jaded) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Between the Buried and Me - Obfuscation (Chezy)
# Between the Buried and Me - Obfuscation (Chezy) audio has already been processed
#
#
# Processing Anti Hero 2, Bill Wurtz - La de Da de Da de Da de Day Oh (CyclopsDragon)
# Bill Wurtz - La de Da de Da de Da de Day Oh (CyclopsDragon) audio has already been processed
#
#
# Processing Anti Hero 2, Black Label Society - Fire It Up (GuitarZero132)
# Black Label Society - Fire It Up (GuitarZero132) audio has already been processed
#
#
# Processing Anti Hero 2, Blind Guardian - The Last Candle (BurpLeTurtle)
# Blind Guardian - The Last Candle (BurpLeTurtle) audio has already been processed
#
#
# Processing Anti Hero 2, blink-182 - Generational Divide (Chezy)
# blink-182 - Generational Divide (Chezy) audio has already been processed
#
#
# Processing Anti Hero 2, BRADIO - Flyers (Supahfast198)
# BRADIO - Flyers (Supahfast198) audio has already been processed
#
#
# Processing Anti Hero 2, braven - NEOLOGISM (Paturages)
# braven - NEOLOGISM (Paturages) audio has already been processed
#
#
# Processing Anti Hero 2, Brian Kahanek - Gemini (GuitarZero132)
# Brian Kahanek - Gemini (GuitarZero132) audio has already been processed
#
#
# Processing Anti Hero 2, Buckethead - Final Wars (Hellrock120)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Buckethead - Final Wars (Hellrock120)\notes.chart is not in .chart format
# Anti Hero 2, Buckethead - Final Wars (Hellrock120) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Buckethead - Nottingham Lace (GuitarZero132)
# 319it [00:03, 95.15it/s]
#
#
# Processing Anti Hero 2, Bumblefoot - Abnormal (GuitarZero132)
# Bumblefoot - Abnormal (GuitarZero132) audio has already been processed
#
#
# Processing Anti Hero 2, Bumblefoot - Raygun (NunoVH)
# Bumblefoot - Raygun (NunoVH) audio has already been processed
#
#
# Processing Anti Hero 2, Bumblefoot - Real (Arctan)
# Bumblefoot - Real (Arctan) audio has already been processed
#
#
# Processing Anti Hero 2, Cacophony - Concerto (Riddo)
# Cacophony - Concerto (Riddo) audio has already been processed
#
#
# Processing Anti Hero 2, Cacophony - Where My Fortune Lies (Arctan)
# Cacophony - Where My Fortune Lies (Arctan) audio has already been processed
#
#
# Processing Anti Hero 2, Cain's Offering - Dawn of Solace (Siavash)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Cain's Offering - Dawn of Solace (Siavash)\notes.chart is not in .chart format
# Anti Hero 2, Cain's Offering - Dawn of Solace (Siavash) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Caligula's Horse - Caligula's Horse Solo Medley (Riddo)
# Caligula's Horse - Caligula's Horse Solo Medley (Riddo) audio has already been processed
#
#
# Processing Anti Hero 2, Camellia - Quaoar (Raspberriel)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Camellia - Quaoar (Raspberriel)\notes.chart is not in .chart format
# Anti Hero 2, Camellia - Quaoar (Raspberriel) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, Car Bomb - Dissect Yourself (XEntombmentX)
# Car Bomb - Dissect Yourself (XEntombmentX) audio has already been processed
#
#
# Processing Anti Hero 2, Cardiacs - Fiery Gun Hand (Chemfinal)
# Cardiacs - Fiery Gun Hand (Chemfinal) audio has already been processed
#
#
# Processing Anti Hero 2, Casiopea - Time Limit (Live) (Smoochums)
# Casiopea - Time Limit (Live) (Smoochums) audio has already been processed
#
#
# Processing Anti Hero 2, Children of Bodom - Towards Dead End (Miscellany)
# Children of Bodom - Towards Dead End (Miscellany) audio has already been processed
#
#
# Processing Anti Hero 2, Chimaira - Pleasure in Pain (XEntombmentX)
# Chimaira - Pleasure in Pain (XEntombmentX) audio has already been processed
#
#
# Processing Anti Hero 2, Chimp Spanner - Mobius (Part III) (Big Whoop Magazine)
# Chimp Spanner - Mobius (Part III) (Big Whoop Magazine) audio has already been processed
#
#
# Processing Anti Hero 2, CHON - Splash (XEntombmentX)
# CHON - Splash (XEntombmentX) audio has already been processed
#
#
# Processing Anti Hero 2, Chris Brooks - Feeding the Myth (feat. Rick Graham) (Riddo)
# Chris Brooks - Feeding the Myth (feat. Rick Graham) (Riddo) audio has already been processed
# 329it [00:03, 94.92it/s]
#
# Processing Anti Hero 2, Circus Maximus - Used (Supahfast198)
# Circus Maximus - Used (Supahfast198) audio has already been processed
#
#
# Processing Anti Hero 2, Closure in Moscow - A Night at the Spleen (Riddo)
# Closure in Moscow - A Night at the Spleen (Riddo) audio has already been processed
#
#
# Processing Anti Hero 2, Conquering Dystopia - Ashes of Lesser Men (Supahfast198)
# Conquering Dystopia - Ashes of Lesser Men (Supahfast198) audio has already been processed
#
#
# Processing Anti Hero 2, courtemanche437 - A Literal Bleep Bloop (courtemanche437)
# courtemanche437 - A Literal Bleep Bloop (courtemanche437) audio has already been processed
#
#
# Processing Anti Hero 2, Crisix - Death by the Fistful of Violence (ThundahK)
# Crisix - Death by the Fistful of Violence (ThundahK) audio has already been processed
#
#
# Processing Anti Hero 2, Crownear - Epos of Shit (Sygenysis)
#
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Crownear - Epos of Shit (Sygenysis)\notes.chart is not in .chart format
# Anti Hero 2, Crownear - Epos of Shit (Sygenysis) .chart file is in the wrong format, skipping
#
#
# Processing Anti Hero 2, cute girls doing cute things - Friends (Mintorment)
# cute girls doing cute things - Friends (Mintorment) audio has already been processed
#
#
# Processing Anti Hero 2, Daisuke Kurosawa - Infinite Rebellion (CyclopsDragon)
# Daisuke Kurosawa - Infinite Rebellion (CyclopsDragon) audio has already been processed
#
#
# Processing Anti Hero 2, Dance Gavin Dance - Chucky vs. The Giant Tortoise (Riddo)
# ...
# ice-l audio has already been processed
#
#
# Processing Guitar Hero X, If Djent Was Added To The Oxford Dictionary
# If Djent Was Added To The Oxford Dictionary audio has already been processed
#
#
# Processing Guitar Hero X, Illumination Theory
# Illumination Theory audio has already been processed
#
#
# Processing Guitar Hero X, impellitteri-impellitterisolom
# impellitteri-impellitterisolom audio has already been processed
# 980it [00:12, 43.43it/s]
#
# Processing Guitar Hero X, Inspion
# Inspion audio has already been processed
#
#
# Processing Guitar Hero X, ironmaiden-phantomoftheopera(l
# ironmaiden-phantomoftheopera(l audio has already been processed
#
#
# Processing Guitar Hero X, joesatriani-satchboogie(live)
# joesatriani-satchboogie(live) audio has already been processed
#
#
# Processing Guitar Hero X, judaspriest-metalmeltdown
# judaspriest-metalmeltdown audio has already been processed
#
#
# Processing Guitar Hero X, Kalra the Everlasting Red
# Kalra the Everlasting Red audio has already been processed
#
#
# Processing Guitar Hero X, ledzepplin-heartbreaker
# ledzepplin-heartbreaker audio has already been processed
#
#
# Processing Guitar Hero X, meatloaf-batoutofhell
# meatloaf-batoutofhell audio has already been processed
#
#
# Processing Guitar Hero X, megadeth-settheworldafire
# megadeth-settheworldafire audio has already been processed
#
#
# Processing Guitar Hero X, meshuggah-clockworks
# 985it [00:12, 43.26it/s]meshuggah-clockworks audio has already been processed
#
#
# Processing Guitar Hero X, metallica-damageinc
# metallica-damageinc audio has already been processed
#
#
# Processing Guitar Hero X, metallica-hitthelights(live_82
# metallica-hitthelights(live_82 audio has already been processed
#
#
# Processing Guitar Hero X, Miasma
# Miasma audio has already been processed
#
#
# Processing Guitar Hero X, michaelshulman-soothsayer(live
# michaelshulman-soothsayer(live audio has already been processed
#
#
# Processing Guitar Hero X, mikeorlando-sonicallystomped
# mikeorlando-sonicallystomped audio has already been processed
#
#
# Processing Guitar Hero X, muse-newborn(live)
# muse-newborn(live) audio has already been processed
#
#
# Processing Guitar Hero X, muse-takeabow
# muse-takeabow audio has already been processed
#
#
# Processing Guitar Hero X, nocturnalbloodlust-maliceagain
# nocturnalbloodlust-maliceagain audio has already been processed
# 997it [00:12, 44.69it/s]
#
# Processing Guitar Hero X, nocturnemoonrise-gateofexpecta
# nocturnemoonrise-gateofexpecta audio has already been processed
#
#
# Processing Guitar Hero X, Numb
# Numb audio has already been processed
#
#
# Processing Guitar Hero X, OldSchool2
# Guitar Hero X, OldSchool2 contains multiple audio files, skipping
#
#
# Processing Guitar Hero X, On And On
# On And On audio has already been processed
#
#
# Processing Guitar Hero X, Oroborus
# Oroborus audio has already been processed
#
#
# Processing Guitar Hero X, pathfinder-readytodiebetweenst
# pathfinder-readytodiebetweenst audio has already been processed
#
#
# Processing Guitar Hero X, paulwardingham-futureshock
# paulwardingham-futureshock audio has already been processed
#
#
# Processing Guitar Hero X, periphery-erised
# periphery-erised audio has already been processed
#
#
# Processing Guitar Hero X, periphery-frakthegods
# periphery-frakthegods audio has already been processed
#
#
# Processing Guitar Hero X, periphery-one(metallicacover)
# periphery-one(metallicacover) audio has already been processed
# 1009it [00:12, 49.85it/s]
#
# Processing Guitar Hero X, periphery-racecar
# periphery-racecar audio has already been processed
#
#
# Processing Guitar Hero X, pinkfloyd-money
# pinkfloyd-money audio has already been processed
#
#
# Processing Guitar Hero X, protestthehero-mist
# protestthehero-mist audio has already been processed
#
#
# Processing Guitar Hero X, protestthehero-softtargetsdigs
# protestthehero-softtargetsdigs audio has already been processed
#
#
# Processing Guitar Hero X, quietriot-cumonfeelthenoise(sl
# quietriot-cumonfeelthenoise(sl audio has already been processed
#
#
# Processing Guitar Hero X, rainbow-alightintheblack
# Guitar Hero X, rainbow-alightintheblack .chart file is in the wrong format, skipping
#
#
# Processing Guitar Hero X, rainbowdragoneyes-chipwrecked
# rainbowdragoneyes-chipwrecked audio has already been processed
#
#
# Processing Guitar Hero X, Raising Hell
# Raising Hell audio has already been processed
#
#
# Processing Guitar Hero X, ringsofsaturn-infused(ft_rusty
# ringsofsaturn-infused(ft_rusty audio has already been processed
#
#
# Processing Guitar Hero X, riot-thundersteel
# riot-thundersteel audio has already been processed
#
#
# Processing Guitar Hero X, Rosanna
# Rosanna audio has already been processed
# 1015it [00:12, 47.78it/s]
#
# Processing Guitar Hero X, RPWSM
# RPWSM audio has already been processed
#
#
# Processing Guitar Hero X, rustycooley-peaceofmind
# rustycooley-peaceofmind audio has already been processed
#
#
# Processing Guitar Hero X, Save You
# Save You audio has already been processed
#
#
# Processing Guitar Hero X, scarsymmetry-neohuman
# scarsymmetry-neohuman audio has already been processed
#
#
# Processing Guitar Hero X, Scuttle Buttin'
# Scuttle Buttin' audio has already been processed
#
#
# Processing Guitar Hero X, shadowwarriors-feelthefire
# shadowwarriors-feelthefire audio has already been processed
#
#
# Processing Guitar Hero X, Shape Of You
# Shape Of You audio has already been processed
#
#
# Processing Guitar Hero X, shinichikobayashi-tofurtherdre
# shinichikobayashi-tofurtherdre audio has already been processed
#
#
# Processing Guitar Hero X, slayer-diebythesword
# slayer-diebythesword audio has already been processed
#
#
# Processing Guitar Hero X, slit-ebico_jioyi
# slit-ebico_jioyi audio has already been processed
# 1028it [00:13, 49.32it/s]
#
# Processing Guitar Hero X, Sober
# Sober audio has already been processed
#
#
# Processing Guitar Hero X, Somewhere Over The Rainbow
# Somewhere Over The Rainbow audio has already been processed
#
#
# Processing Guitar Hero X, sonataarctica-stilllovingyou(s
# sonataarctica-stilllovingyou(s audio has already been processed
#
#
# Processing Guitar Hero X, stevenwilson-drivehome
# stevenwilson-drivehome audio has already been processed
#
#
# Processing Guitar Hero X, stevevai-firegardensuite
# stevevai-firegardensuite audio has already been processed
#
#
# Processing Guitar Hero X, stratovarius-elysium
# stratovarius-elysium audio has already been processed
#
#
# Processing Guitar Hero X, Strobe (Sparkee Remix)
# Strobe (Sparkee Remix) audio has already been processed
#
#
# Processing Guitar Hero X, sunlessrise-sunlessrisesolomed
# sunlessrise-sunlessrisesolomed audio has already been processed
# 1034it [00:13, 48.58it/s]
#
# Processing Guitar Hero X, symphonyx-underworldsolomedley
# symphonyx-underworldsolomedley audio has already been processed
#
#
# Processing Guitar Hero X, symphonyx-withoutyou
# symphonyx-withoutyou audio has already been processed
#
#
# Processing Guitar Hero X, takayoshiohmura-thecataclysm
# takayoshiohmura-thecataclysm audio has already been processed
#
#
# Processing Guitar Hero X, Tallulah
# Tallulah audio has already been processed
#
#
# Processing Guitar Hero X, The Bitter End
# The Bitter End audio has already been processed
#
#
# Processing Guitar Hero X, The Scales Of Strangeness
# The Scales Of Strangeness audio has already been processed
#
#
# Processing Guitar Hero X, theocracy-bethlehem
# theocracy-bethlehem audio has already been processed
#
#
# Processing Guitar Hero X, thinlizzy-coldsweat
# Guitar Hero X, thinlizzy-coldsweat contains multiple audio files, skipping
#
#
# Processing Guitar Hero X, This Is Forever
# This Is Forever audio has already been processed
#
#
# Processing Guitar Hero X, Time Stands Still
# 1039it [00:32,  1.00it/s]
#
# Processing Guitar Hero X, Unholy Gravebirth
# 1040it [00:45,  1.85s/it]
#
# Processing Guitar Hero X, vektor-destroyingthecosmos
# 1041it [01:09,  3.80s/it]
#
# Processing Guitar Hero X, vitalism-pagan
# 1042it [01:24,  5.07s/it]
#
# Processing Guitar Hero X, What's Up, People
# 1043it [01:38,  6.28s/it]
#
# Processing Guitar Hero X, wintersun-wintermadness
# 1044it [01:55,  8.09s/it]
#
# Processing Guitar Hero X, xi-parousia
# 1045it [02:11,  9.57s/it]
#
# Processing Guitar Hero X, yngwiemalmsteen-mr_crowley(ozz
# 1046it [02:28, 11.27s/it]
#
# Processing Guitar Hero X, yngwiemalmsteen-priestoftheunh
# 1047it [02:52, 14.22s/it]
#
# Processing Guitar Hero X, Your Majesty
# 1048it [03:05, 13.75s/it]
#
# Processing Guitar Hero X, Yu-Gi-Oh! Guitar Battle
# 1049it [03:25, 15.42s/it]
#
# Processing Paradigm, AAAA & Umeboshi Chazuke - Sayonara Cosmonaut
# 1051it [03:33, 10.65s/it]
#
# Processing Paradigm, Alan Walker - Alone
#
#
# Processing Paradigm, Alter Bridge - Metalingus
# 1053it [03:57, 11.02s/it]
#
# Processing Paradigm, Arion - Seven
# 1054it [04:13, 12.18s/it]
#
# Processing Paradigm, Asleep Droid - Dithering
# 1055it [04:24, 11.87s/it]
#
# Processing Paradigm, AXS Solo Medley
# 1056it [04:52, 16.08s/it]
#
# Processing Paradigm, Berried Alive - Ancient Skies
# 1057it [05:20, 19.15s/it]
#
# Processing Paradigm, BGH Music - Best Of Impossible Remix 2018
# 1058it [05:38, 18.66s/it]
#
# Processing Paradigm, Bobo
# 1059it [05:51, 17.06s/it]
#
# Processing Paradigm, Breaking Benjamin - Blood
# 1060it [06:01, 15.19s/it]
#
# Processing Paradigm, Buckethead - Romero One Mind Any Weapon
# 1061it [06:31, 19.43s/it]
#
# Processing Paradigm, Bum cover
# 1062it [06:56, 21.05s/it]
#
# Processing Paradigm, Burn MF - Five Finger Death Punch
# 1063it [07:08, 18.57s/it]
#
# Processing Paradigm, CFO$ - Catch Your Breath
# 1064it [07:17, 15.67s/it]
#
# Processing Paradigm, Circus For a Psycho - Skillet
# 1065it [07:30, 14.91s/it]
#
# Processing Paradigm, Crazy Bus
# 1066it [07:39, 12.96s/it]
#
# Processing Paradigm, Danny Johnson - Into Thin Air
# 1067it [08:40, 27.53s/it]
#
# Processing Paradigm, Disturbed - The Best Ones Lie
# Paradigm, Disturbed - The Best Ones Lie contains multiple audio files, skipping
#
#
# Processing Paradigm, Dragonforce - Revolution Deathsquad
# 1069it [09:07, 20.86s/it]
#
# Processing Paradigm, Dream Theater - Untethered Angel
# 1070it [09:27, 20.77s/it]
#
# Processing Paradigm, Escape the Fate - Live Fast, Die Beautiful
# 1071it [09:40, 18.68s/it]
#
# Processing Paradigm, ETERNAL NOW
# 1072it [09:53, 17.22s/it]
#
# Processing Paradigm, Evanescence - My Immortal
# 1073it [10:09, 16.81s/it]
#
# Processing Paradigm, Exilelord Solo Medley
# 1074it [10:36, 19.65s/it]
#
# Processing Paradigm, Faithless - Black Veil Brides
# 1075it [10:52, 18.71s/it]
#
# Processing Paradigm, Fearofdark - There'll Always Be Next Year
# 1076it [11:06, 17.34s/it]
#
# Processing Paradigm, Frontline - Pillar
# 1077it [11:17, 15.36s/it]
#
# Processing Paradigm, Full Tank
# 1078it [11:34, 16.01s/it]
#
# Processing Paradigm, Galneryus - Cry for the Dark
# 1079it [11:53, 16.68s/it]
#
# Processing Paradigm, Ghost - Square Hammer
# 1080it [12:06, 15.61s/it]
#
# Processing Paradigm, GHOST DATA - Celestial Bodies
# 1081it [12:21, 15.67s/it]
#
# Processing Paradigm, Gloryhammer - Gloryhammer
# 1082it [12:38, 15.92s/it]
#
# Processing Paradigm, Gott mit uns - Sabaton
# 1083it [12:49, 14.47s/it]
#
# Processing Paradigm, Harsh Poetry - Diabarha
# 1084it [13:17, 18.62s/it]
#
# Processing Paradigm, Hertz Devil - Apocynthion Drive
# 1085it [13:37, 18.88s/it]
#
# Processing Paradigm, I Want Out - Helloween
# 1086it [13:52, 17.87s/it]
#
# Processing Paradigm, I won't see you tonight
# 1087it [14:37, 25.89s/it]
#
# Processing Paradigm, Infected Mushroom - The Pretender
# 1088it [14:59, 24.59s/it]
#
# Processing Paradigm, Instant Reality - Chimera King
# 1089it [15:09, 20.29s/it]
#
# Processing Paradigm, Jarvis9999 Solo Medley
# 1090it [15:49, 26.18s/it]
#
# Processing Paradigm, Jesus Slaves - Bad Wolves
# 1091it [16:01, 21.98s/it]
#
# Processing Paradigm, Jonathan Young & Lee Albrecht - Zombie
# 1092it [16:16, 19.80s/it]
#
# Processing Paradigm, Journey
# 1093it [16:35, 19.75s/it]
#
# Processing Paradigm, Keiichi Sugiyama - Everwinter
# 1094it [16:44, 16.53s/it]
#
# Processing Paradigm, Kevin Sherwood+Maluka - Where Are We Going
# 1095it [17:01, 16.70s/it]
#
# Processing Paradigm, Killing With Fire - Ignition
# 1096it [17:15, 15.87s/it]
#
# Processing Paradigm, Killswitch Engage - This Fire Burns
# 1097it [17:26, 14.19s/it]
#
# Processing Paradigm, KRVKT- Nihilanth
# 1098it [17:38, 13.56s/it]
#
# Processing Paradigm, Kuroma - Field Kaerezu no Chi
# 1099it [17:49, 12.89s/it]
#
# Processing Paradigm, laamaa - nuri brut
# 1100it [17:57, 11.46s/it]
#
# Processing Paradigm, Leaf - Calamity Fortune
# 1101it [18:18, 14.36s/it]
#
# Processing Paradigm, Lies
# 1102it [18:40, 16.63s/it]
#
# Processing Paradigm, Little Tybee - More Like Jason
# 1103it [18:53, 15.62s/it]
#
# Processing Paradigm, Livewire
# 1104it [19:12, 16.65s/it]
#
# Processing Paradigm, Marc Andre Hamilion - Pop Music
# 1105it [19:24, 15.15s/it]
#
# Processing Paradigm, Mental Prolapse - Rings of Saturn
# 1106it [19:39, 15.18s/it]
#
# Processing Paradigm, Metallica - Enter Sandman
# 1107it [19:58, 16.10s/it]
#
# Processing Paradigm, Metea11 Solo Medley
# 1108it [20:21, 18.33s/it]
#
# Processing Paradigm, Mike Orlando - Changes
# 1109it [20:39, 18.06s/it]
#
# Processing Paradigm, Monster (DOTEXE Remix)
# 1110it [20:51, 16.36s/it]
#
# Processing Paradigm, Mr. Fastfinger - Tapping Boogie
# 1111it [21:10, 17.23s/it]
#
# Processing Paradigm, Noisia - Groundhog
# 1112it [21:34, 19.09s/it]
#
# Processing Paradigm, OISHII - ONIGIRI FREEWAY
# 1113it [21:53, 19.21s/it]
#
# Processing Paradigm, Paradigm
# 1114it [22:42, 28.23s/it]
#
# Processing Paradigm, Paralyzer - Finger Eleven
# 1115it [23:06, 26.81s/it]
#
# Processing Paradigm, Phonetic Hero - PUBSTEP
# 1116it [23:32, 26.64s/it]
#
# Processing Paradigm, PixelGH Solo Medley
# 1117it [24:30, 35.98s/it]
#
# Processing Paradigm, Powerwolf - Die, Die, Crucified
# 1118it [24:40, 28.25s/it]
#
# Processing Paradigm, Press Start - MDK
# 1119it [24:52, 23.30s/it]
#
# Processing Paradigm, Renaissance
# 1120it [25:07, 20.75s/it]
#
# Processing Paradigm, Rob Scallon - Taking Pick Scraping Too Far
# 1121it [25:18, 17.88s/it]
#
# Processing Paradigm, Schmutz06 Solo Medley
# 1122it [25:49, 21.72s/it]
#
# Processing Paradigm, Second & Sebring - Of Mice and Men
# 1123it [26:01, 19.03s/it]
#
# Processing Paradigm, Shaman's Harvest - Broken Dreams
# 1124it [26:17, 18.04s/it]
#
# Processing Paradigm, Shinedown - Cut the Cord
# 1125it [26:36, 18.45s/it]
#
# Processing Paradigm, Shipwrecked (Drop Goblin Remix) - Alestorm
# 1126it [27:15, 24.54s/it]
#
# Processing Paradigm, Sidney600 Solo Medley
# 1127it [27:50, 27.78s/it]
#
# Processing Paradigm, Sink or Swim - Falling In Reverse
# 1128it [28:06, 24.20s/it]
#
# Processing Paradigm, Sixx_A.M. - Stars
# 1129it [28:19, 20.76s/it]
#
# Processing Paradigm, Soil the Stillborn
# 1130it [28:33, 18.62s/it]
#
# Processing Paradigm, Soinhumane Solo Medley
# 1131it [29:07, 23.20s/it]
#
# Processing Paradigm, Sons Of Apollo - Signs Of The Time
# 1132it [29:29, 22.91s/it]
#
# Processing Paradigm, Spazzmatica Polka - Kevin MacLeod
# 1133it [29:48, 21.73s/it]
#
# Processing Paradigm, Staple Tapeworms On My Penis
# 1134it [30:00, 18.87s/it]
#
# Processing Paradigm, Struggle Lovers - IRONBUNNY
# 1135it [30:12, 16.82s/it]
#
# Processing Paradigm, Synth Battle Vs DeadShadow
# 1136it [30:28, 16.59s/it]
#
# Processing Paradigm, Synth Battle vs Hyper
# 1137it [30:39, 14.88s/it]
#
# Processing Paradigm, Synth Battle vs PixelGH
# 1138it [30:48, 13.22s/it]
#
# Processing Paradigm, Synth Battle Vs. SuccymcSuccerson
# 1139it [31:07, 14.76s/it]
#
# Processing Paradigm, Synth Battle vs. Zeppy
# 1140it [31:53, 24.13s/it]
#
# Processing Paradigm, Take What You Want
# 1141it [32:26, 27.01s/it]
#
# Processing Paradigm, Tattered Banners and Bloody Flags - Amon Amarth
# 1142it [32:41, 23.42s/it]
#
# Processing Paradigm, The Calling - All That Remains
# 1143it [32:53, 19.99s/it]
#
# Processing Paradigm, The Triple T Terrorbyte Trance Techno Thing
#
# The chart at X:\Training Data\Unprocessed\Paradigm\The Triple T Terrorbyte Trance Techno Thing\notes.chart is not in .chart format
# Paradigm, The Triple T Terrorbyte Trance Techno Thing .chart file is in the wrong format, skipping
#
#
# Processing Paradigm, Three Days Grace - World So Cold
# 1145it [33:07, 13.87s/it]
#
# Processing Paradigm, Top of the World 2 - Stephen Walking
# 1146it [33:42, 19.22s/it]
#
# Processing Paradigm, Track on Fire
# 1147it [34:01, 19.16s/it]
#
# Processing Paradigm, Unbreakable - Fireflight
# 1148it [34:29, 21.36s/it]
#
# Processing Paradigm, Village C - Perfect World
# 1149it [34:36, 17.47s/it]
#
# Processing Paradigm, Virt - Bedtime Story
# 1150it [34:48, 15.77s/it]
#
# Processing Paradigm, You Love Her Coz She's Dead - Dead End
# 1151it [35:01,  1.83s/it]

# %%
print('{:4.2f} Gigabytes of song data'.format(song_size))
print('{:3.2f} Gigabytes of notes data'.format(notes_size))
# Out:
# 59.22 Gigabytes of song data
# 0.75 Gigabytes of notes data
