# %% [markdown]
# The purpose of this notebook is to create the outline for a function which processes all of the training data and extracts useful information.

# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
sys.path.insert(1, str(Path().resolve().parent) + r'\Preprocessing')
from chart_functions import chart2tensor, get_configuration
import pickle
import numpy as np

unprocessed_data_path = Path(r'X:\Training Data\Unprocessed')
processed_data_path = Path(r'X:\Training Data\Processed')

# %% [markdown]
# Things to measure from the data
# - File list
#     - Audio files present (distribution of .ogg files)
#     - Which track pack the song is from
# - Song data
#     - Song length (given in milliseconds)
#     - Genre
#     - Delay
# - Note information
#     - How many of each type of note there is
# - Total size of training data
#     - Measured by song file size + chart file size

# %%
next(os.walk(unprocessed_data_path))[1]
# Out:
# ['Angevil Hero II',
#  'Anti Hero',
#  'Anti Hero 2',
#  'Community Track Pack 6',
#  'Digitizer',
#  'Facelift Pack 1',
#  'Facelift Pack 2',
#  'Focal Point',
#  'Guitar Hero X',
#  'Paradigm']

# %%
ogg_list = {}     # How many audio files of type .ogg per folder
mp3_list = {}     # How many audio files of type .mp3 per folder
wav_list = {}     # How many audio files of type .wav per folder
track_pack = {}   # Distribution of songs per track pack
lengths = []      # Song lengths in seconds
sizes = {}         # Size of training data per track pack
genres = {}       # Distribution of song genres
delays = {}       # Distribution of delay

for dirName, subdirList, fileList in os.walk(unprocessed_data_path):  # Walk through training data directory
    if not fileList:  # If file list is empty
        continue
    # Get song data
    try:
        configuration = get_configuration(dirName)
    except:
        print('configuration of {} encoded improperly'.format(dirName))
        continue
    
    # Get track pack
    track_pack_ = str(Path(dirName).parent).split('\\')[3]
    # print('Track Pack: %s' % str(Path(dirName).parent).split('\\')[3])
    if track_pack_ not in track_pack.keys():
        track_pack[track_pack_] = 1
    else:
        track_pack[track_pack_] += 1

    # Get audio file list
    num_ogg_files = 0
    num_mp3_files = 0
    num_wav_files = 0
    mp3 = False         # Boolean to determine if songs are in mp3 format
    wav = False
    for track in fileList:
        if track.endswith('.ogg'):
            num_ogg_files += 1
        if track.endswith('.mp3'):
            num_mp3_files += 1
        if track.endswith('.wav'):
            num_wav_files += 1
    if num_ogg_files > 0:
        if num_ogg_files not in ogg_list.keys():
            ogg_list[num_ogg_files] = 1
        else:
            ogg_list[num_ogg_files] += 1
    if num_mp3_files > 0:
        mp3 = True
        if num_mp3_files not in mp3_list.keys():
            mp3_list[num_mp3_files] = 1
        else:
            mp3_list[num_mp3_files] += 1
    if num_wav_files > 0:
        wav = True
        if num_wav_files not in wav_list.keys():
            wav_list[num_wav_files] = 1
        else:
            wav_list[num_wav_files] += 1
    
    
    # Get lengths
    try:    # Sometimes there's an extra space at the end of the key of configuration
        lengths.append(int(configuration['song_length ']) / 1000)  # ms -> s
    except:
        if 'song_length' in configuration.keys():
            try:
                lengths.append(int(configuration['song_length']) / 1000)  # ms -> s
            except:
                print('song_length for {} unavailable'.format(dirName))
        else:
            print('No song length available for {}'.format(dirName))
    # Get genres
    try:
        if 'genre ' in configuration.keys():
            if configuration['genre '] not in genres.keys():
                genres[configuration['genre ']] = 1
            else:
                genres[configuration['genre ']] += 1
    except:
        if 'genre' in configuration.keys():
            if configuration['genre'] not in genres.keys():
                genres[configuration['genre']] = 1
            else:
                genres[configuration['genre']] += 1
    # Get delays
    try:
        if 'delay ' in configuration.keys():
            if configuration['delay '] not in delays.keys():
                delays[configuration['delay ']] = 1
            else:
                delays[configuration['delay ']] += 1
    except:
        if 'delay' in configuration.keys():
            if configuration['delay'] not in delays.keys():
                delays[configuration['delay']] = 1
            else:
                delays[configuration['delay']] += 1

    # Get size of data
    if num_ogg_files > 1 or num_mp3_files > 1:
        continue # Skip files with separated sources
    if mp3:
        audio_file_name = [i for i in fileList if i.endswith('.mp3')][0]
        audio_file_path = Path(dirName).joinpath(audio_file_name)
        chart_file_path = Path(dirName).joinpath('notes.chart')
        size = (audio_file_path.stat().st_size + chart_file_path.stat().st_size) / 1e9
    elif wav:
        audio_file_name = [i for i in fileList if i.endswith('.wav')][0]
        audio_file_path = Path(dirName).joinpath(audio_file_name)
        chart_file_path = Path(dirName).joinpath('notes.chart')
        size = (audio_file_path.stat().st_size + chart_file_path.stat().st_size) / 1e9
    else:
        audio_file_name = [i for i in fileList if i.endswith('.ogg')][0]
        
    audio_file_path = Path(dirName).joinpath(audio_file_name)
    chart_file_path = Path(dirName).joinpath('notes.chart')
    try:
        size = (audio_file_path.stat().st_size + chart_file_path.stat().st_size) / 1e9
    except:
        print('{} not in .chart format'.format(str(chart_file_path).split('\\')[-3:-1]))

    if track_pack_ not in sizes.keys():
        sizes[track_pack_] = size
    else:
        sizes[track_pack_] += size
    
    length = sum(lengths)
    length_h = length/(60**2)

print('\n\nTrack pack distribution: ', track_pack)
print('.ogg files: ', ogg_list)
print('.mp3 files: ', mp3_list)
print('.wav files: ', wav_list)
print('Delays: ', delays)
print('Sizes: ', sizes)
print('Hours of Music: {}'.format(length_h))
# Out:
# No song length available for X:\Training Data\Unprocessed\Angevil Hero II\5. Exodus - Funeral Hymn
# No song length available for X:\Training Data\Unprocessed\Anti Hero\At the Throne of Judgment - Mariner's Cutlass (DeathofTeyolia)
# No song length available for X:\Training Data\Unprocessed\Anti Hero\Brand New - Degausser (Chezy)
# No song length available for X:\Training Data\Unprocessed\Anti Hero\Job For A Cowboy - The Synthetic Sea (DeathofTeyolia)
# No song length available for X:\Training Data\Unprocessed\Anti Hero\Unearth - The Swarm (DeathofTeyolia)
# ['Anti Hero 2', '50 Cent - Ayo Technology (feat. Justin Timberlake) (Siavash)'] not in .chart format
# ['Anti Hero 2', 'ABBA - Gimme! Gimme! Gimme! (Raspberriel)'] not in .chart format
# ['Anti Hero 2', 'Afterglow - Lost One no Goukoku (Neru cover) (Raspberriel)'] not in .chart format
# ['Anti Hero 2', 'Aquellex - Wanderflux (Raspberriel)'] not in .chart format
# ['Anti Hero 2', 'Arch Enemy - Vultures (Sygenysis)'] not in .chart format
# configuration of X:\Training Data\Unprocessed\Anti Hero 2\Architects - 01. Death Is Not Defeat (XEntombmentX) encoded improperly
# ['Anti Hero 2', 'Ark Storm - Play for You (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Avatar - Glory to Our King Legend of the King (Hellrock120)
# ['Anti Hero 2', 'Avatar - Glory to Our King Legend of the King (Hellrock120)'] not in .chart format
# ['Anti Hero 2', 'Bad Religion - I Want to Conquer the World (Siavash)'] not in .chart format
# ['Anti Hero 2', 'Baroness - A Horse Called Golgotha (Sygenysis)'] not in .chart format
# ['Anti Hero 2', 'Ben Folds Five - One Angry Dwarf and 200 Solemn Faces (Jaded)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Buckethead - Final Wars (Hellrock120)
# ['Anti Hero 2', 'Buckethead - Final Wars (Hellrock120)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Cain's Offering - Dawn of Solace (Siavash)
# ['Anti Hero 2', "Cain's Offering - Dawn of Solace (Siavash)"] not in .chart format
# ['Anti Hero 2', 'Camellia - Quaoar (Raspberriel)'] not in .chart format
# ['Anti Hero 2', 'Crownear - Epos of Shit (Sygenysis)'] not in .chart format
# ['Anti Hero 2', 'Darkwater - Breathe (Hellrock120)'] not in .chart format
# ['Anti Hero 2', 'Dispatch - The General (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\DragonForce - Give Me the Night (Siavash)
# ['Anti Hero 2', 'DragonForce - Give Me the Night (Siavash)'] not in .chart format
# configuration of X:\Training Data\Unprocessed\Anti Hero 2\Electronic Boutique - Miles (Akira Sora) encoded improperly
# ['Anti Hero 2', 'EndeverafteR - Baby Baby Baby (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Frenzy - Shred or Die (Anti Hero Team)
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Haunt - Burst into Flame (Sygenysis)
# ['Anti Hero 2', 'Haunt - Burst into Flame (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\HIDDEN MACHINE - 01. Cut (feat. Lucas Mann) (Jarvis9999)
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\HIDDEN MACHINE - 02. Fly (Jarvis9999)
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\HIDDEN MACHINE - 03. Surf (Jarvis9999)
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\HIDDEN MACHINE - 08. Dive (feat. ichika) (Jarvis9999)
# ['Anti Hero 2', 'Incubus - Anna Molly (Jaded)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 01. Novus Inceptum Severe Emotional Distress (Sygenysis)
# ['Anti Hero 2', 'Into Eternity - 01. Novus Inceptum Severe Emotional Distress (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 03. Nothing (feat. Collin Craig) (Sygenysis)
# ['Anti Hero 2', 'Into Eternity - 03. Nothing (feat. Collin Craig) (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 04. Timeless Winter (Sygenysis)
# ['Anti Hero 2', 'Into Eternity - 04. Timeless Winter (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 05. Out (Sygenysis)
# ['Anti Hero 2', 'Into Eternity - 05. Out (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 06. A Past Beyond Memory (Sygenysis)
# ['Anti Hero 2', 'Into Eternity - 06. A Past Beyond Memory (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 07. Surrounded by Night (Sygenysis)
# ['Anti Hero 2', 'Into Eternity - 07. Surrounded by Night (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 08. Eternal (Sygenysis)
# ['Anti Hero 2', 'Into Eternity - 08. Eternal (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 09. Pain Through Breathing (Sygenysis)
# ['Anti Hero 2', 'Into Eternity - 09. Pain Through Breathing (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 10. Suspension of Disbelief (Sygenysis)
# ['Anti Hero 2', 'Into Eternity - 10. Suspension of Disbelief (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 11. Paralyzed (Sygenysis)
# ['Anti Hero 2', 'Into Eternity - 11. Paralyzed (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - The Scattering of Ashes Solo Medley (Sygenysis, CyclopsDragon)
# ['Anti Hero 2', 'Into Eternity - The Scattering of Ashes Solo Medley (Sygenysis, CyclopsDragon)'] not in .chart format
# ['Anti Hero 2', 'Junior Senior - Move Your Feet (Jaded)'] not in .chart format
# ['Anti Hero 2', 'Kendrick Lamar - i (Raspberriel)'] not in .chart format
# ['Anti Hero 2', 'Lizzo - Tempo (feat. Missy Elliot) (Jaded)'] not in .chart format
# ['Anti Hero 2', 'Matt Land - Pamela (Siavash)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Mötley Crüe - Kickstart My Heart (Dance with the Dead Remix) (Sygenysis)
# ['Anti Hero 2', 'Mötley Crüe - Kickstart My Heart (Dance with the Dead Remix) (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Periphery - Marigold (Jaded)
# ['Anti Hero 2', 'Periphery - Marigold (Jaded)'] not in .chart format
# ['Anti Hero 2', 'Periphery - One (Metallica cover) (Jaded)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Persefone - Inner Fullness (Hellrock120)
# ['Anti Hero 2', 'Persefone - Inner Fullness (Hellrock120)'] not in .chart format
# ['Anti Hero 2', 'Rage Against the Machine - Know Your Enemy (feat. Maynard James Keenan) (Raspberriel)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Rigor Mortis - Speed Whore Afterbirth of a Midget (S.Y.G.D.P.) (Sygenysis)
# ['Anti Hero 2', 'Rigor Mortis - Speed Whore Afterbirth of a Midget (S.Y.G.D.P.) (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Ripe - Goon Squad (Jaded)
# ['Anti Hero 2', 'Ripe - Goon Squad (Jaded)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Rob Scallon & Sarah Longfield - Payback (Slayer cover) (Raspberriel)
# ['Anti Hero 2', 'Rob Scallon & Sarah Longfield - Payback (Slayer cover) (Raspberriel)'] not in .chart format
# ['Anti Hero 2', 'Savage Grace - Savage Grace Discography Solo Medley (Sygenysis)'] not in .chart format
# ['Anti Hero 2', 'Say Anything - Mara and Me (Jaded)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Scanner - Puppet on a String (feat. Ralf Scheepers) (Sygenysis)
# ['Anti Hero 2', 'Scanner - Puppet on a String (feat. Ralf Scheepers) (Sygenysis)'] not in .chart format
# ['Anti Hero 2', 'Scorpions - Dynamite (Raspberriel)'] not in .chart format
# ['Anti Hero 2', 'Secret & Whisper - Spider Besider (Jaded)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Shadow of Intent - Barren and Breathless Macrocosm (feat. Trevor Strnad) (Miscellany)
# ['Anti Hero 2', 'Shredding the Envelope - Shredding the Envelope (feat. Joe Stump) (Sygenysis)'] not in .chart format
# configuration of X:\Training Data\Unprocessed\Anti Hero 2\Slayer - Dittohead (ThundahK) encoded improperly
# ['Anti Hero 2', 'Sonata Arctica - Sonata Arctica 1999-2000 Solo Medley (Siavash)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Sonata Arctica - The Cage (Siavash)
# ['Anti Hero 2', 'Sonata Arctica - The Cage (Siavash)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Space Eater - FAA (Miscellany)
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Tankard - The Prisoner (Iron Maiden cover) (Sygenysis)
# ['Anti Hero 2', 'Tankard - The Prisoner (Iron Maiden cover) (Sygenysis)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\The Black Eyed Peas - Pump It (Jaded)
# ['Anti Hero 2', 'The Black Eyed Peas - Pump It (Jaded)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\The Brian Setzer Orchestra - Rock This Town (Raspberriel)
# ['Anti Hero 2', 'The Brian Setzer Orchestra - Rock This Town (Raspberriel)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\The Johnson Mountain Boys - Going to Georgia (Live) (Sygenysis)
# ['Anti Hero 2', 'The Johnson Mountain Boys - Going to Georgia (Live) (Sygenysis)'] not in .chart format
# ['Anti Hero 2', 'The Monkees - Valleri (Sygenysis)'] not in .chart format
# ['Anti Hero 2', 'The Pretenders - Middle of the Road (Raspberriel)'] not in .chart format
# ['Anti Hero 2', 'The Red Jumpsuit Apparatus - Face Down (Jaded)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Anti Hero 2\Toxik - World Circus (Miscellany)
# ['Anti Hero 2', 'xi - Double Helix (Raspberriel)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\2313
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\9patternsofeternalpain
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Au Canada
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Breakthrough
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Bytes
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Chaosfonia II
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Dexterous Disco - Pizzachamp
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\don't skip leg day
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\End of Aeon
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Gigi Sabani Died for our Sins
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Girls and their Smiles
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Pizza's Hell
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Precipitation 2
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Raiding The Icy Town
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Regen
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Repetitivity
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Sea of Stars
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\sentimental
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Sin of Envy
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Sin of Gluttony
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Sin of Sloth
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Spank Me Daddy
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Summer Synth 4 (Autumn's Uprising)
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Survivors
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Techno Bass Neon Romance
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\This Went Too Far
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\TrainSurfing
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Transcending Beyond Flesh
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\Warp Speed
# No song length available for X:\Training Data\Unprocessed\Community Track Pack 6\X Kirby - No Fucks Were Given
# ['Digitizer', '2. Dejo & Bon - Wheelpower & Go! (Siavash)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Amberian Dawn - Circus Black (CyclopsDragon)
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Attack Attack! - Stick Stickly (Jaded)
# ['Facelift Pack 1', 'Attack Attack! - Stick Stickly (Jaded)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Between the Buried and Me - Selkies The Endless Obsession (Jaded)
# song_length for X:\Training Data\Unprocessed\Facelift Pack 1\Buckethead - Soothsayer (xX760Xx) unavailable
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Children of Bodom - If You Want Peace... Prepare for War (Miscellany)
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\In Flames - Take This Life (CyclopsDragon)
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\iwrestledabearonce - Tastes Like Kevin Bacon (Jaded)
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Joe Perry - Joe Perry Guitar Battle (GuitarZero132)
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\John 5 featuring Jim Root - Black Widow of La Porte (xX760Xx)
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Machine Head - Aesthetics of Hate (Raspberriel)
# ['Facelift Pack 1', 'Machine Head - Aesthetics of Hate (Raspberriel)'] not in .chart format
# song_length for X:\Training Data\Unprocessed\Facelift Pack 1\Metallica - Dyers Eve (xX760Xx) unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 1\Metallica - Ride the Lightning (xX760Xx) unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 1\Metallica - Trapped Under Ice (xX760Xx) unavailable
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Nevermore - Without Morals (CyclopsDragon)
# ['Facelift Pack 1', 'Nothing More - Fat Kid (Jaded)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Red Hot Chili Peppers - Knock Me Down (Raspberriel)
# ['Facelift Pack 1', 'Red Hot Chili Peppers - Knock Me Down (Raspberriel)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Ronald Jenkees - Guitar Sound (Supah)
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Scorpions - No One Like You (Raspberriel)
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Skeletonwitch - Crushed Beyond Dust (CyclopsDragon)
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\Steve Vai - For The Love Of God (xX760Xx)
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 1\The Edgar Winter Group - Frankenstein (Raspberriel)
# ['Facelift Pack 1', 'The Edgar Winter Group - Frankenstein (Raspberriel)'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\Black Tide - Shockwave [Raspberriel]
# ['Facelift Pack 2', 'Black Tide - Shockwave [Raspberriel]'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\Blue Öyster Cult - (Don't Fear) The Reaper [Sygenysis]
# ['Facelift Pack 2', "Blue Öyster Cult - (Don't Fear) The Reaper [Sygenysis]"] not in .chart format
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\1. Holy Wars... The Punishment Due [xX760Xx] unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\10. My Creation [xX760Xx] unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\11. Rust in Peace Solo Medley [xX760Xx & Miscellany] unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\2. Hangar 18 [xX760Xx] unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\3. Take No Prisoners [xX760Xx] unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\4. Five Magics [xX760Xx] unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\5. Poison Was the Cure [xX760Xx] unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\6. Lucretia [xX760Xx] unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\7. Tornado of Souls [xX760Xx] unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\8. Dawn Patrol [xX760Xx] unavailable
# song_length for X:\Training Data\Unprocessed\Facelift Pack 2\Megadeth - Rust in Peace Full Album [xX760Xx]\9. Rust in Peace... Polaris [xX760Xx] unavailable
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\Pantera - Cowboys from Hell [Miscellany]
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\Prototype - The Way it Ends [Miscellany]
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\Queens of the Stone Age - No One Knows [3-UP]
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\Red Hot Chili Peppers - Higher Ground (Stevie Wonder Cover) [Raspberriel]
# ['Facelift Pack 2', 'Red Hot Chili Peppers - Higher Ground (Stevie Wonder Cover) [Raspberriel]'] not in .chart format
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\Styx - Renegade [ΩHM]
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\The Black Dahlia Murder - What a Horrible Night to Have a Curse [Miscellany]
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\The Jimi Hendrix Experience - Fire (Live at Woodstock) [GuitarZero132]
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\Tool - Schism [3-UP]
# No song length available for X:\Training Data\Unprocessed\Facelift Pack 2\Yngwie Malmsteen's Rising Force - Caprici di Diablo [CyclopsDragon]
# No song length available for X:\Training Data\Unprocessed\Paradigm\Burn MF - Five Finger Death Punch
# No song length available for X:\Training Data\Unprocessed\Paradigm\Escape the Fate - Live Fast, Die Beautiful
# No song length available for X:\Training Data\Unprocessed\Paradigm\Frontline - Pillar
# No song length available for X:\Training Data\Unprocessed\Paradigm\Gloryhammer - Gloryhammer
# No song length available for X:\Training Data\Unprocessed\Paradigm\Gott mit uns - Sabaton
# No song length available for X:\Training Data\Unprocessed\Paradigm\Harsh Poetry - Diabarha
# No song length available for X:\Training Data\Unprocessed\Paradigm\I Want Out - Helloween
# No song length available for X:\Training Data\Unprocessed\Paradigm\Jesus Slaves - Bad Wolves
# No song length available for X:\Training Data\Unprocessed\Paradigm\Mental Prolapse - Rings of Saturn
# No song length available for X:\Training Data\Unprocessed\Paradigm\Paralyzer - Finger Eleven
# No song length available for X:\Training Data\Unprocessed\Paradigm\Powerwolf - Die, Die, Crucified
# No song length available for X:\Training Data\Unprocessed\Paradigm\Press Start - MDK
# No song length available for X:\Training Data\Unprocessed\Paradigm\Second & Sebring - Of Mice and Men
# No song length available for X:\Training Data\Unprocessed\Paradigm\Shinedown - Cut the Cord
# No song length available for X:\Training Data\Unprocessed\Paradigm\Shipwrecked (Drop Goblin Remix) - Alestorm
# No song length available for X:\Training Data\Unprocessed\Paradigm\Sink or Swim - Falling In Reverse
# No song length available for X:\Training Data\Unprocessed\Paradigm\Spazzmatica Polka - Kevin MacLeod
# No song length available for X:\Training Data\Unprocessed\Paradigm\The Calling - All That Remains
# No song length available for X:\Training Data\Unprocessed\Paradigm\Top of the World 2 - Stephen Walking
# No song length available for X:\Training Data\Unprocessed\Paradigm\Unbreakable - Fireflight
# No song length available for X:\Training Data\Unprocessed\Paradigm\Village C - Perfect World
#
#
# Track pack distribution:  {'Angevil Hero II': 67, 'Anti Hero': 171, 'Anti Hero 2': 361, 'Community Track Pack 6': 59, 'Digitizer': 82, 'Facelift Pack 1': 35, 'Facelift Pack 2': 51, 'Focal Point': 82, 'Guitar Hero X': 127, 'Paradigm': 101}
# .ogg files:  {1: 919, 2: 8, 3: 5, 4: 5, 5: 1}
# .mp3 files:  {1: 194, 2: 4}
# .wav files:  {1: 5}
# Delays:  {0: 138, 2000: 1, -30: 1}
# Sizes:  {'Angevil Hero II': 0.5877250020000001, 'Anti Hero': 1.5027012299999993, 'Anti Hero 2': 3.4878409429999992, 'Community Track Pack 6': 0.6517439810000001, 'Digitizer': 0.905170514, 'Facelift Pack 1': 0.2888009099999999, 'Facelift Pack 2': 0.46382963699999996, 'Focal Point': 0.8020256750000004, 'Guitar Hero X': 0.9147779689999999, 'Paradigm': 0.6988158280000001}
# Hours of Music: 82.97431305555558

# %%
# Plotting
plt.hist(genres);
plt.figure()
plt.hist(lengths);

# %% [markdown]
# The following section will analyze the note composition of each song.
#
# - For each song
#     - Get the notes
#     - Create a folder in "processed" if one doesn't exist already
#     - Into that folder, put
#         - Dictionary of note distribution
#     - Record...
#         - Total note distribution per track pack
#             - Held
#             - Released
#             - Notes
#             - Modifier

# %%
def check_multiple_audio_files(fileList):
    # Get audio file list
    num_files = 0
    multiple_files = False
    mp3 = False         # Boolean to determine if songs are in mp3 format
    wav = False
    for track in fileList:
        if track.endswith('.ogg'):
            num_files += 1
        if track.endswith('.mp3'):
            num_files += 1
        if track.endswith('.wav'):
            num_files += 1
    if num_files > 1:
        multiple_files = True
    return multiple_files

# %%
# load dictionaries
dict_path = Path.cwd().parent / 'Resources'

with open(dict_path / 'combo_dict.pkl', 'rb') as handle:
    combo_dict = pickle.load(handle)
with open(dict_path / 'hold_dict.pkl', 'rb') as handle:
    hold_dict = pickle.load(handle)
with open(dict_path / 'modifier_dict.pkl', 'rb') as handle:
    modifier_dict = pickle.load(handle)
with open(dict_path / 'note_dict.pkl', 'rb') as handle:
    note_dict = pickle.load(handle)

# %%
num_zero = 0                # To measure sparsity of notes
num_nonzero = 0
wrong_format_charts = []    # Holds paths to charts not in .chart format
multiple_audio_songs = []   # Holds paths to charts with multiple audio files
modifier = []               # Holds tapped vs forced vs regulat
held = []                   # Holds held, released, or neither
dense_notes_agg = []        # Holds all notes that aren't zero
for dirName, subdirList, fileList in os.walk(unprocessed_data_path):  # Walk through training data directory
    if not fileList:  # If file list is empty
        continue
    track_pack_ = str(Path(dirName).parent).split('\\')[3]
    song_ = str(Path(dirName)).split('\\')[4]
    processed_song_path = processed_data_path / track_pack_ / song_
    unprocessed_song_path = unprocessed_data_path / track_pack_ / song_

    print('Processing {}, {}'.format(track_pack_, song_))

    # Skip creating the directory if there is more than one audio file
    if check_multiple_audio_files(fileList):
        multiple_audio_songs.append(unprocessed_song_path)
        continue

    if not processed_song_path.exists():
        os.mkdir(processed_song_path)
    
    # Create note tensor for song
    # print('\nGetting notes for %s' % song_)
    try:
        note_tensor = np.array(chart2tensor(unprocessed_song_path / 'notes.chart', print_release_notes = False)).astype(int)
    except:
        wrong_format_charts.append(unprocessed_song_path)
        continue

    # Analyze for sparsity (number of zeros / total notes)
    num_zero += np.count_nonzero(note_tensor == 0)
    num_nonzero += (len(note_tensor) - np.count_nonzero(note_tensor == 0))

    # dense_notes is the note tensor with all the zeros removed
    dense_notes = note_tensor[note_tensor != 0]

    # Parse through dense_notes, extracting information
    for x in dense_notes:
        ''' Uncomment the next line if memory can handle it '''
        # dense_notes_agg.extend(dense_notes)
        modifier.append(modifier_dict[x])
        held.append(hold_dict[x])

print('\nticks with notes = ', num_nonzero)
print('ticks without notes = ', num_zero)
print('sparsity = %4.5f' % (num_nonzero / (num_nonzero + num_zero)))
print('Charts in bad format: ', len(wrong_format_charts))
print('Songs with multiple audio files: ', len(multiple_audio_songs))
# Out:
# Processing Angevil Hero II, 1. Andy McKee - Ouray
# Processing Angevil Hero II, 1. Joe Satriani - The Forgotten (Part One + Part Two)
# Processing Angevil Hero II, 1. John 5 - 27 Needles
# Processing Angevil Hero II, 1. Lordi - Mr. Killjoy
# Processing Angevil Hero II, 1. Megadeth - Kick the Chair
# Processing Angevil Hero II, 1. Paul Gilbert - 2 Become 1 (Spice Girls Cover)
# Processing Angevil Hero II, 1. Protest the Hero - Limb from Limb (with Intro)
# Processing Angevil Hero II, 1. Protest the Hero - Wretch (with Intro)
# Processing Angevil Hero II, 1. Scar Symmetry - Dreaming 24_7
# Processing Angevil Hero II, 1. Syu - Guitar Demonstration #2
# Processing Angevil Hero II, 1. Trivium - To the Rats
# Processing Angevil Hero II, 2. Dark Tranquillity - Punish My Heaven
# Processing Angevil Hero II, 2. Death - Spirit Crusher
# Processing Angevil Hero II, 2. Mastodon - Blood and Thunder
# Processing Angevil Hero II, 2. Megadeth - Chosen Ones
# Processing Angevil Hero II, 2. Metalium - Free Forever
# Processing Angevil Hero II, 2. Spastic Ink - The Mad Data Race
# Processing Angevil Hero II, 2. The Hellecasters - Help I've Fallen (& I Can't Get Up)
# Processing Angevil Hero II, 2. Venom - Witching Hour
# Processing Angevil Hero II, 2. Vision Divine - La Vita Fugge (Chapter VI)
# Processing Angevil Hero II, 2. Warmen - Return of Salieri
# Processing Angevil Hero II, 2. Yngwie J. Malmsteen's Rising Force - Blitzkrieg
# Processing Angevil Hero II, 3. Dio - Rainbow in the Dark
# Processing Angevil Hero II, 3. Immortal - At the Heart of Winter
# Processing Angevil Hero II, 3. Impellitteri - Race Into the Light
# Processing Angevil Hero II, 3. Luca Turilli - Black Dragon
# Processing Angevil Hero II, 3. Michael Romeo - Paganini - Concerto in B Minor
# Processing Angevil Hero II, 3. Mötley Crüe - Dr. Feelgood
# Processing Angevil Hero II, 3. Necrophagist - Stabwound
# Processing Angevil Hero II, 3. Nevermore - The Psalm of Lydia
# Processing Angevil Hero II, 3. Steve Vai - Erotic Nightmares
# Processing Angevil Hero II, 3. Trivium - Insurrection
# Processing Angevil Hero II, 3. Yngwie J. Malmsteen's Rising Force - Asylum
# Processing Angevil Hero II, 4. Alter Bridge - Ahavo Rabo Taco Salad
# Processing Angevil Hero II, 4. Amon Amarth - Asator
# Processing Angevil Hero II, 4. Andromeda - Morphing Into Nothing
# Processing Angevil Hero II, 4. Blind Guardian - Banish from Sanctuary
# Processing Angevil Hero II, 4. Divine Heresy - Failed Creation
# Processing Angevil Hero II, 4. Gentaro Satomura - Attack of the Aliens
# Processing Angevil Hero II, 4. Kid Rock - Cowboy
# Processing Angevil Hero II, 4. Megadeth - I Thought I Knew it All
# Processing Angevil Hero II, 4. Paul Gilbert - I Feel Love (Donna Summer Cover)
# Processing Angevil Hero II, 4. Stratovarius - Fire Dance
# Processing Angevil Hero II, 4. Warmen - Beyond Abilities
# Processing Angevil Hero II, 5. Dying Fetus - Homicidal Retribution
# Processing Angevil Hero II, 5. Eric Sardinas - Down in the Bottom
# Processing Angevil Hero II, 5. Exodus - Funeral Hymn
# Processing Angevil Hero II, 5. Joe Satriani - Big Bad Moon
# Processing Angevil Hero II, 5. Lostprophets - Kobrakai
# Processing Angevil Hero II, 5. Loudness - You Shook Me
# Processing Angevil Hero II, 5. Megadeth - Back in the Day
# Processing Angevil Hero II, 5. Megadeth - Blood of Heroes
# Processing Angevil Hero II, 5. SIAM SHADE - Triptych
# Processing Angevil Hero II, 5. Sinergy - The Warrior Princess
# Processing Angevil Hero II, 5. Spastic Ink - Multi-Masking
# Processing Angevil Hero II, 6. 3 Inches of Blood - Axes of Evil
# Processing Angevil Hero II, 6. All Shall Perish - Never...Again
# Processing Angevil Hero II, 6. Avenged Sevenfold - Dancing Dead
# Processing Angevil Hero II, 6. Coroner - Nosferatu
# Processing Angevil Hero II, 6. Dethklok - Murdertrain a Comin'
# Processing Angevil Hero II, 6. Dir En Grey - Agitated Screams of Maggots
# Processing Angevil Hero II, 6. Jason Becker - Paganini's 5th Caprice
# Processing Angevil Hero II, 6. John Petrucci - Animate-Inanimate
# Processing Angevil Hero II, 6. Megadeth - Something That I'm Not
# Processing Angevil Hero II, 6. Norther - Nothing Left
# Processing Angevil Hero II, 6. Sinergy - I Spit on Your Grave
# Processing Angevil Hero II, 7. The Hellecasters - Orange Blossom Special
# Processing Anti Hero, 01. Brave This Storm (Miscellany)
# Processing Anti Hero, 01. Broken Soul (Chezy)
# Processing Anti Hero, 01. Human Disaster (Chezy)
# Processing Anti Hero, 01. The Primeval Dark (DigitalSquirrel)
# Processing Anti Hero, 02. Cauterizer (Chezy)
# Processing Anti Hero, 02. Sweetest Poison (Chezy)
# Processing Anti Hero, 02. While We Sleep (Digitalsquirrel)
# Processing Anti Hero, 03. Pseudo Self (Chezy)
# Processing Anti Hero, 03. Revelation (DigitalSquirrel)
# Processing Anti Hero, 03. Send Help (Chezy)
# Processing Anti Hero, 03. Strife (Miscellany)
# Processing Anti Hero, 04. Black Heart Rebellion (Digitalsquirrel)
# Processing Anti Hero, 04. Defenseless (Chezy)
# Processing Anti Hero, 04. Holy Walls of the Vatican (Chezy)
# Processing Anti Hero, 05. Lose To Night (DigitalSquirrel)
# Processing Anti Hero, 05. The Void (Chezy)
# Processing Anti Hero, 05. VVorld Demise (Chezy)
# Processing Anti Hero, 06. At the End of This War (Miscellany)
# Processing Anti Hero, 06. Collapsing Words (DigitalSquirrel)
# Processing Anti Hero, 06. Inner Demons (Chezy)
# Processing Anti Hero, 06. Nailgun (Chezy)
# Processing Anti Hero, 07. Decamilli (Chezy)
# Processing Anti Hero, 07. Graveyard Shift (Chezy)
# Processing Anti Hero, 07. The River (DigitalSquirrel)
# Processing Anti Hero, 08. Bridgepainter (Chezy)
# Processing Anti Hero, 08. Ephemeral (Digitalsquirrel)
# Processing Anti Hero, 08. Nooses (Chezy)
# Processing Anti Hero, 08. Villainy Thrives (Miscellany)
# Processing Anti Hero, 09. Incineration - The Broken World (Miscellany)
# Processing Anti Hero, 09. The Promethean Song (DigitalSquirrel)
# Processing Anti Hero, 09. The Tightrope (Chezy)
# Processing Anti Hero, 09. Whale Shark (Chezy)
# Processing Anti Hero, 09_The Tempest (Chemfinal)
# Processing Anti Hero, 1 -  . _ _ _ _
# Processing Anti Hero, 10. Delusionalisphere (Chezy)
# Processing Anti Hero, 10. Illuminate (Chezy)
# Processing Anti Hero, 10. Shadows of the Dying Sun (DigitalSquirrel)
# Processing Anti Hero, 10. Wake (The End Is Nigh) (Miscellany)
# Processing Anti Hero, 11. Bloodwork (Chezy)
# Processing Anti Hero, 11. Observer (Chezy)
# Processing Anti Hero, 11. Out to the Sea (Insomnium)
# Processing Anti Hero, 12. As I Am Exploding (Miscellany)
# Processing Anti Hero, 13_I Can Never Go Home (Reprise) (Chemfinal)
# Processing Anti Hero, 14. Losing My Religion (R.E.M Cover) (Miscellany)
# Processing Anti Hero, 2 - . . _ _ _
# Processing Anti Hero, 3 - . . . _ _ (Ft. Fabrizio Leo)
# Processing Anti Hero, 4 - . . . . _
# Processing Anti Hero, 5 -
# Processing Anti Hero, A Night In The Abyss - Deicide (Chezy)
# Processing Anti Hero, Abiogenesis - Visualize (Chezy)
# Processing Anti Hero, Aborted - Retrogore (DeathofTeyolia)
# Processing Anti Hero, Akira Sora - Columpio (DigitalSquirrel)
# Processing Anti Hero, All Shall Perish - Procession of Ashes (DeathofTeyolia)
# Processing Anti Hero, Allegaeon - Threshold of Perception (DeathofTeyolia)
# Processing Anti Hero, Alterbeast - Ancient's Retribution (deathofteyolia)
# Processing Anti Hero, Alterbeast - Throne of Maggots (ChemFinal)
# Processing Anti Hero, And Hell Followed With - One Of The Swarm (DeathofTeyolia)
# Processing Anti Hero, AngelMaker - Abysmal (DeathofTeyolia)
# Processing Anti Hero, AngelMaker - Leech (DeathofTeyolia)
# Processing Anti Hero, Animals as Leaders - The Glass Bridge (Dillski)
# Processing Anti Hero, Anterior - Seraph (DeathofTeyolia)
# Processing Anti Hero, Area 11 - Dream and Reality (DigitalSquirrel)
# Processing Anti Hero, Artificial Language - Mazes (DeathofTeyolia)
# Processing Anti Hero, As Blood Runs Black - Resist (DeathofTeyolia)
# Processing Anti Hero, As I Lay Dying - Forsaken (DeathofTeyolia)
# Processing Anti Hero, As I Lay Dying - The Plague (DeathofTeyolia)
# Processing Anti Hero, At the Gates - Slaughter of the Soul (DeathofTeyolia)
# Processing Anti Hero, At the Throne of Judgment - Mariner's Cutlass (DeathofTeyolia)
# Processing Anti Hero, Atlantis Chronicles - The Odysseus (DeathofTeyolia)
# Processing Anti Hero, Audioslave - Exploder (Chezy)
# Processing Anti Hero, August Burns Red - Dangerous (DeathofTeyolia)
# Processing Anti Hero, Beneath The Sky - 7861 (DeathofTeyolia)
# Processing Anti Hero, Beyond Creation - Omnipresent Perception (DeathofTeyolia)
# Processing Anti Hero, Billy Ray Cyrus - I Want My Mullet Back (Chezy)
# Processing Anti Hero, blink-182 - Bottom Of The Ocean (Chezy)
# Processing Anti Hero, Bloodshot Dawn - Inadequacy (DeathofTeyolia)
# Processing Anti Hero, Bloodshot Dawn - The Image Faded (DigitalSquirrel)
# Processing Anti Hero, Brand New - Degausser (Chezy)
# Processing Anti Hero, Brandon Ellis - No Escape (Chezy)
# Processing Anti Hero, Bullet For My Valentine - 4 Words (To Choke Upon) (DeathofTeyolia)
# Processing Anti Hero, Cattle Decapitation - Pacific Grim (DeathofTeyolia)
# Processing Anti Hero, Chimaira - Resurrection (Digitalsquirrel)
# Processing Anti Hero, Conducting from the Grave - Eternally Gutted
# Processing Anti Hero, Conducting from the Grave - What Monsters We Have Become 1 & 2 (DeathofTeyolia)
# Processing Anti Hero, Counterparts - Drown (Chezy)
# Processing Anti Hero, David Maxim Micic - Rise and Shine (ft. Jakub Zytechi) (Dillski)
# Processing Anti Hero, Dawn of Disease - Through Nameless Ages (DeathofTeyolia)
# Processing Anti Hero, Decrepit Birth - (A Departure Of The Sun) Ignite The Tesla Coil (DeathofTeyolia)
# Processing Anti Hero, Depths of Hatred - Ministry of Deceit (DeathofTeyolia)
# Processing Anti Hero, Desolace - Green (DeathofTeyolia)
# Processing Anti Hero, Destiny Potato - Blue Sun (Dillski)
# Processing Anti Hero, Destrage - Collateral Pleasure (DeathofTeyolia)
# Processing Anti Hero, Die From Sorrow - Sea of Rebirth (DigitalSquirrel)
# Processing Anti Hero, DigitalSquirrel - You're Out (DigitalSquirrel)
# Processing Anti Hero, Disfigured Elegance - The Last Disease (DeathofTeyolia)
# Processing Anti Hero, Don Broco - Actors (Chezy)
# Processing Anti Hero, Erra - Hybrid Earth (DeathofTeyolia)
# Processing Anti Hero, Fallujah - Cerebral Hybridization (DeathofTeyolia)
# Processing Anti Hero, FamilyJules - Super Mario Bros. Theme (ft. John Petrucci) (Dillski)
# Processing Anti Hero, Fire Within - Artificial Perception (DigitalSquirrel)
# Processing Anti Hero, Fit for an Autopsy - Black Mammoth (DeathofTeyolia)
# Processing Anti Hero, Fleshgod Apocalypse - Conspiracy of Silence (Chemfinal)
# Processing Anti Hero, From the Shallows - Battle Axe (DeathofTeyolia)
# Processing Anti Hero, Galneryus - Face to the Real (Chemfinal)
# Processing Anti Hero, Galneryus - Holding the Broken Wings (Chemfinal)
# Processing Anti Hero, Gravemind - Anaesthesia (DeathofTeyolia)
# Processing Anti Hero, Hail the Sun - Will They Blame Me If You Go Disappearing (Chezy)
# Processing Anti Hero, Hechizeros Band - El Sonidito (Chezy)
# Processing Anti Hero, Hellborg, Lane, Sipe - Rice with the Angels (Live) (Chemfinal)
# Processing Anti Hero, Hellions - Nightliner Rhapsody (Chezy)
# Processing Anti Hero, i built the sky - Stratiformis (ft. Jake Howsam Lowe) (Dillski)
# Processing Anti Hero, Ignominious Incarceration - The Saviour (DeathofTeyolia)
# Processing Anti Hero, Impending Doom - Anything Goes (Chezy)
# Processing Anti Hero, Inferi - Marching Through The Flames Of Tyranny (DeathofTeyolia)
# Processing Anti Hero, Intervals - Belvedere (DeathofTeyolia)
# Processing Anti Hero, Jason Becker - Serrana (Chemfinal)
# Processing Anti Hero, Jason Richardson - Fragments (feat. Lukas Magyar & Mark Holcomb) (DeathofTeyolia)
# Processing Anti Hero, Job For A Cowboy - The Synthetic Sea (DeathofTeyolia)
# Processing Anti Hero, Kero Kero Bonito - Flamingo (Chezy)
# Processing Anti Hero, Killswitch Engage - Numbered Days (DeathofTeyolia)
# Processing Anti Hero, Limp Bizkit - The Truth (m9)
# Processing Anti Hero, Little Tybee - Golden Delilah (ChemFinal)
# Processing Anti Hero, Lorna Shore - Flesh Coffin (DeathofTeyolia)
# Processing Anti Hero, Luck Wont Save You - Alone In Reverie (DeathofTeyolia)
# Processing Anti Hero, Machinae Supremacy - All of My Angels (DigitalSquirrel)
# Processing Anti Hero, Miss May I - Apologies Are for the Weak (DeathofTeyolia)
# Processing Anti Hero, Necrophagist - Fermented Offal Discharge (Chezy)
# Processing Anti Hero, No Bragging Rights - And They Threatened Us With Fire (Chezy) [ENCORE]
# Processing Anti Hero, Noel Pix - Die Legende (m9)
# Processing Anti Hero, Oath to Order - White Widow (DeathofTeyolia)
# Processing Anti Hero, Oathbreaker - Second Son Of R (Chezy)
# Processing Anti Hero, Parasite Inc. - Fire the Machines + Back For War (DeathofTeyolia)
# Processing Anti Hero, Parkway Drive - A Deathless Song (Chezy)
# Processing Anti Hero, Parkway Drive - Gimme A D (DeathofTeyolia)
# Processing Anti Hero, Persefone - Spirals Within Thy Being (Chemfinal)
# Processing Anti Hero, Phinehas - Hell Below (DeathofTeyolia)
# Processing Anti Hero, Polaris - Lucid (Chezy)
# Processing Anti Hero, Pronostic - Becik (DeathofTeyolia)
# Processing Anti Hero, Rings of Saturn - Desolate Paradise (DigitalSquirrel)
# Processing Anti Hero, Rings of Saturn - Immemorial Essence (DeathofTeyolia)
# Processing Anti Hero, Rings of Saturn - Margidda (DigitalSquirrel)
# Processing Anti Hero, Rolo Tomassi - Stage Knives (Chezy)
# Processing Anti Hero, Scar Symmetry - The Path of Least Resistance (DeathofTeyolia)
# Processing Anti Hero, Sentinels - Consequent Aversion (DeathofTeyolia)
# Processing Anti Hero, Shadows Fall - The Unknown (DeathofTeyolia)
# Processing Anti Hero, Shokran - The Blood & Creatures from the Mud (DeathofTeyolia)
# Processing Anti Hero, Shores Of Elysium - Mindsculpt (DeathofTeyolia)
# Processing Anti Hero, Shylmagoghnar - I Am the Abyss (DigitalSquirrel)
# Processing Anti Hero, Slaughter to Prevail - Crowned & Conquered (feat. Lucas Mann)
# Processing Anti Hero, Spite - Kill or Be Killed (DeathofTeyolia)
# Processing Anti Hero, Starset - Bringing It Down (Digitalsquirrel)
# Processing Anti Hero, Starset - Into The Unknown (DigitalSquirrel)
# Processing Anti Hero, T-Square - Truth (Chemfinal)
# Processing Anti Hero, The Acacia Strain - Tactical Nuke (Chezy)
# Processing Anti Hero, The Air I Breathe - Take This to Heart (DeathofTeyolia)
# Processing Anti Hero, The Black Dahlia Murder - Deathmask Divine (Chezy)
# Processing Anti Hero, The Black Dahlia Murder - Receipt (DeathofTeyolia)
# Processing Anti Hero, The Contortionist - Oscillator (DeathofTeyolia)
# Processing Anti Hero, The Raven Autarchy - The Obscene Deliverance (DeathofTeyolia)
# Processing Anti Hero, The Zenith Passage - Deus Deceptor (DeathofTeyolia)
# Processing Anti Hero, Throne Of The Beheaded - Reformation (feat. Aleksander Abdulov) (DeathofTeyolia)
# Processing Anti Hero, Unearth - Eyes of Black (DeathofTeyolia)
# Processing Anti Hero, Unearth - The Swarm (DeathofTeyolia)
# Processing Anti Hero, Until We Die - As Fear Became Reality (DeathofTeyolia)
# Processing Anti Hero, Vale Of Pnath - Heart Of Darkness (DeathofTeyolia)
# Processing Anti Hero, Vektor - Dying World (Chemfinal)
# Processing Anti Hero, Virulent Depravity - Your Demise (DeathofTeyolia)
# Processing Anti Hero, Vitalij Kuprij - Opus 1 (Theme by Paganini) (Chemfinal)
# Processing Anti Hero, Wage War - Witness (DeathofTeyolia)
# Processing Anti Hero, Within the Ruins - Clockwork (DeathofTeyolia)
# Processing Anti Hero, Within the Ruins - Feast or Famine (Chezy)
# Processing Anti Hero 2, 50 Cent - Ayo Technology (feat. Justin Timberlake) (Siavash)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\50 Cent - Ayo Technology (feat. Justin Timberlake) (Siavash)\notes.chart is not in .chart format
# Processing Anti Hero 2, ABBA - Gimme! Gimme! Gimme! (Raspberriel)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\ABBA - Gimme! Gimme! Gimme! (Raspberriel)\notes.chart is not in .chart format
# Processing Anti Hero 2, Adam Neely - 7 11 (Paturages)
# Processing Anti Hero 2, Adam Nitti - Antisocialmedia (JoeyD)
# Processing Anti Hero 2, AFI - Get Dark (Chezy)
# Processing Anti Hero 2, Afterglow - Lost One no Goukoku (Neru cover) (Raspberriel)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Afterglow - Lost One no Goukoku (Neru cover) (Raspberriel)\notes.chart is not in .chart format
# Processing Anti Hero 2, Alhambra - Alhambra Solo Medley (Chemfinal)
# Processing Anti Hero 2, Alhambra - Missing You (Chemfinal)
# Processing Anti Hero 2, Allegaeon - 1.618 (Miscellany)
# Processing Anti Hero 2, Allegaeon - Apoptosis (Miscellany)
# Processing Anti Hero 2, Alter Bridge - Isolation (Jaded)
# Processing Anti Hero 2, Andy Timmons - Carpe Diem (Arctan)
# Processing Anti Hero 2, Andy Timmons - Farmer Sez (Arctan)
# Processing Anti Hero 2, Angel Vivaldi - Acid Reign (Dillski)
# Processing Anti Hero 2, Angel Vivaldi - Synapse Solo Medley (Dillski, Siavash, CyclopsDragon)
# Processing Anti Hero 2, Animals as Leaders - Arithmophobia (XEntombmentX)
# Processing Anti Hero 2, Anthrax - Subjugator (ThundahK)
# Processing Anti Hero 2, Anubis Gate - Desiderio Omnibus (Supahfast198)
# Processing Anti Hero 2, Apocalyptica - Path (Mintorment)
# Processing Anti Hero 2, Aquellex - Wanderflux (Raspberriel)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Aquellex - Wanderflux (Raspberriel)\notes.chart is not in .chart format
# Processing Anti Hero 2, Arch Echo - 01. Daybreak (gaebpls)
# Processing Anti Hero 2, Arch Echo - 02. Immediate Results (gaebpls)
# Processing Anti Hero 2, Arch Echo - 03. Stella (gaebpls)
# Processing Anti Hero 2, Arch Echo - 04. Aurora (gaebpls)
# Processing Anti Hero 2, Arch Echo - 05. Mukduk (gaebpls)
# Processing Anti Hero 2, Arch Echo - 06. Tempest (gaebpls)
# Processing Anti Hero 2, Arch Echo - 07. Bocksuvfun (gaebpls)
# Processing Anti Hero 2, Arch Echo - 08. Iris (gaebpls)
# Processing Anti Hero 2, Arch Echo - You Won't Believe This Solo Medley (gaebpls, CyclopsDragon)
# Processing Anti Hero 2, Arch Enemy - Vultures (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Arch Enemy - Vultures (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Architects - 01. Death Is Not Defeat (XEntombmentX)
# Processing Anti Hero 2, Architects - 02. Hereafter (Chezy)
# Processing Anti Hero 2, Architects - 03. Mortal After All (XEntombmentX)
# Processing Anti Hero 2, Architects - 04. Holy Hell (Miscellany)
# Processing Anti Hero 2, Architects - 05. Damnation (Miscellany)
# Processing Anti Hero 2, Architects - 06. Royal Beggars (XEntombmentX)
# Processing Anti Hero 2, Architects - 07. Modern Misery (XEntombmentX)
# Processing Anti Hero 2, Architects - 08. Dying to Heal (Chezy)
# Processing Anti Hero 2, Architects - 09. The Seventh Circle (Miscellany)
# Processing Anti Hero 2, Architects - 10. Doomsday (Miscellany)
# Processing Anti Hero 2, Architects - 11. A Wasted Hymn (Chezy)
# Processing Anti Hero 2, Architects - Holy Hell Riff Medley (XEntombmentX, Chezy, Miscellany)
# Processing Anti Hero 2, ArchWk - Red Shift (ArchWk)
# Processing Anti Hero 2, Ark Storm - Play for You (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Ark Storm - Play for You (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Art Tatum - Tiger Rag (Arctan)
# Processing Anti Hero 2, Avatar - Glory to Our King Legend of the King (Hellrock120)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Avatar - Glory to Our King Legend of the King (Hellrock120)\notes.chart is not in .chart format
# Processing Anti Hero 2, Avenged Sevenfold - Second Heartbeat (XEntombmentX)
# Processing Anti Hero 2, Bad Religion - I Want to Conquer the World (Siavash)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Bad Religion - I Want to Conquer the World (Siavash)\notes.chart is not in .chart format
# Processing Anti Hero 2, Baroness - A Horse Called Golgotha (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Baroness - A Horse Called Golgotha (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Bayside - Rumspringa (Return to Heartbreak Road) (Chezy)
# Processing Anti Hero 2, Beartooth - Used and Abused (Chezy)
# Processing Anti Hero 2, Ben Folds Five - One Angry Dwarf and 200 Solemn Faces (Jaded)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Ben Folds Five - One Angry Dwarf and 200 Solemn Faces (Jaded)\notes.chart is not in .chart format
# Processing Anti Hero 2, Between the Buried and Me - Obfuscation (Chezy)
# Processing Anti Hero 2, Bill Wurtz - La de Da de Da de Da de Day Oh (CyclopsDragon)
# Processing Anti Hero 2, Black Label Society - Fire It Up (GuitarZero132)
# Processing Anti Hero 2, Blind Guardian - The Last Candle (BurpLeTurtle)
# Processing Anti Hero 2, blink-182 - Generational Divide (Chezy)
# Processing Anti Hero 2, BRADIO - Flyers (Supahfast198)
# Processing Anti Hero 2, braven - NEOLOGISM (Paturages)
# Processing Anti Hero 2, Brian Kahanek - Gemini (GuitarZero132)
# Processing Anti Hero 2, Buckethead - Final Wars (Hellrock120)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Buckethead - Final Wars (Hellrock120)\notes.chart is not in .chart format
# Processing Anti Hero 2, Buckethead - Nottingham Lace (GuitarZero132)
# Processing Anti Hero 2, Bumblefoot - Abnormal (GuitarZero132)
# Processing Anti Hero 2, Bumblefoot - Raygun (NunoVH)
# Processing Anti Hero 2, Bumblefoot - Real (Arctan)
# Processing Anti Hero 2, Cacophony - Concerto (Riddo)
# Processing Anti Hero 2, Cacophony - Where My Fortune Lies (Arctan)
# Processing Anti Hero 2, Cain's Offering - Dawn of Solace (Siavash)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Cain's Offering - Dawn of Solace (Siavash)\notes.chart is not in .chart format
# Processing Anti Hero 2, Caligula's Horse - Caligula's Horse Solo Medley (Riddo)
# Processing Anti Hero 2, Camellia - Quaoar (Raspberriel)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Camellia - Quaoar (Raspberriel)\notes.chart is not in .chart format
# Processing Anti Hero 2, Car Bomb - Dissect Yourself (XEntombmentX)
# Processing Anti Hero 2, Cardiacs - Fiery Gun Hand (Chemfinal)
# Processing Anti Hero 2, Casiopea - Time Limit (Live) (Smoochums)
# Processing Anti Hero 2, Children of Bodom - Towards Dead End (Miscellany)
# Processing Anti Hero 2, Chimaira - Pleasure in Pain (XEntombmentX)
# Processing Anti Hero 2, Chimp Spanner - Mobius (Part III) (Big Whoop Magazine)
# Processing Anti Hero 2, CHON - Splash (XEntombmentX)
# Processing Anti Hero 2, Chris Brooks - Feeding the Myth (feat. Rick Graham) (Riddo)
# Processing Anti Hero 2, Circus Maximus - Used (Supahfast198)
# Processing Anti Hero 2, Closure in Moscow - A Night at the Spleen (Riddo)
# Processing Anti Hero 2, Conquering Dystopia - Ashes of Lesser Men (Supahfast198)
# Processing Anti Hero 2, courtemanche437 - A Literal Bleep Bloop (courtemanche437)
# Processing Anti Hero 2, Crisix - Death by the Fistful of Violence (ThundahK)
# Processing Anti Hero 2, Crownear - Epos of Shit (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Crownear - Epos of Shit (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, cute girls doing cute things - Friends (Mintorment)
# Processing Anti Hero 2, Daisuke Kurosawa - Infinite Rebellion (CyclopsDragon)
# Processing Anti Hero 2, Dance Gavin Dance - Chucky vs. The Giant Tortoise (Riddo)
# Processing Anti Hero 2, Dance Gavin Dance - Man of the Year (Miscellany)
# Processing Anti Hero 2, Darkest Hour - An Ethereal Drain (ThundahK)
# Processing Anti Hero 2, Darkwater - Breathe (Hellrock120)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Darkwater - Breathe (Hellrock120)\notes.chart is not in .chart format
# Processing Anti Hero 2, Darude - Sandstorm (XEntombmentX)
# Processing Anti Hero 2, David Wise - Diddy Kong Racing Theme (JoeyD)
# Processing Anti Hero 2, Death - Spirit Crusher (xX760Xx)
# Processing Anti Hero 2, Death Ohagi - Master of Puppets (feat. Hatsune Miku & Megurine Luka) (CyclopsDragon)
# Processing Anti Hero 2, Derek Sherinian - Ghost Runner (Supahfast198)
# Processing Anti Hero 2, Dick Dale and His Del-Tones - Hava Nagila (GuitarZero132)
# Processing Anti Hero 2, Dirty Loops - Roller Coaster (Justin Bieber cover) (JoeyD)
# Processing Anti Hero 2, Dispatch - The General (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Dispatch - The General (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Divine Realm - Abyssal Light (Dillski)
# Processing Anti Hero 2, Drago Drago Forcito - Through the Fire and Flamingos (Chezy)
# Processing Anti Hero 2, DragonForce - Evil Dead (Death cover) (Miscellany)
# Processing Anti Hero 2, DragonForce - Give Me the Night (Siavash)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\DragonForce - Give Me the Night (Siavash)\notes.chart is not in .chart format
# Processing Anti Hero 2, DragonForce - Heroes of Our Time (Riddo)
# Processing Anti Hero 2, DragonForce - War! (EvaCH)
# Processing Anti Hero 2, Ekali & 1788-L - R U I N (Mintorment)
# Processing Anti Hero 2, Electronic Boutique - Miles (Akira Sora)
# Processing Anti Hero 2, EndeverafteR - Baby Baby Baby (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\EndeverafteR - Baby Baby Baby (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Eric Johnson - Righteous (JoeyD)
# Processing Anti Hero 2, Exivious - Deeply Woven (Big Whoop Magazine)
# Processing Anti Hero 2, Exmortus - Metal Is King (ThundahK)
# Processing Anti Hero 2, Exodus - Bonded by Banjo (Miscellany)
# Processing Anti Hero 2, Exodus - Call to Arms Riot Act (Miscellany)
# Processing Anti Hero 2, Firewind - The Departure Heading for the Dawn (Roy Knight)
# Processing Anti Hero 2, Frank Zappa and the Mothers of Invention - Fifty-Fifty (Smoochums)
# Processing Anti Hero 2, Frenzy - Shred or Die (Anti Hero Team)
# Processing Anti Hero 2, Galneryus - 01. Premonition (Chemfinal)
# Processing Anti Hero 2, Galneryus - 02. The Time Before Dawn (Chemfinal)
# Processing Anti Hero 2, Galneryus - 03. Raise My Sword (Chemfinal)
# Processing Anti Hero 2, Galneryus - 04. The Voice of Grievous Cry (Chemfinal)
# Processing Anti Hero 2, Galneryus - 05. Rain of Tears (Chemfinal)
# Processing Anti Hero 2, Galneryus - 06. Reward for Betrayal (Chemfinal)
# Processing Anti Hero 2, Galneryus - 07. Soul of the Field (Chemfinal)
# Processing Anti Hero 2, Galneryus - 08. Chain of Distress (Chemfinal)
# Processing Anti Hero 2, Galneryus - 09. The Force of Courage (Chemfinal)
# Processing Anti Hero 2, Galneryus - Under the Force of Courage Solo Medley (Chemfinal)
# Processing Anti Hero 2, Gama Bomb - Shitting Yourself to Live (ThundahK)
# Processing Anti Hero 2, Greg Howe - Direct Injection (Arctan)
# Processing Anti Hero 2, Guitar Heroes - 12 Donkeys (xX760Xx)
# Processing Anti Hero 2, Guthrie Govan - Hollywood Woman (JoeyD)
# Processing Anti Hero 2, Hannah Montana - Nobody's Perfect (Miscellany)
# Processing Anti Hero 2, Haunt - Burst into Flame (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Haunt - Burst into Flame (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Haywyre - Contagious (JoeyD)
# Processing Anti Hero 2, Haywyre - Square One (Mintorment)
# Processing Anti Hero 2, Hear 'n Aid - Stars (Miscellany)
# Processing Anti Hero 2, Heavenly - Virus Solo Medley (CyclopsDragon)
# Processing Anti Hero 2, HIDDEN MACHINE - 01. Cut (feat. Lucas Mann) (Jarvis9999)
# Processing Anti Hero 2, HIDDEN MACHINE - 02. Fly (Jarvis9999)
# Processing Anti Hero 2, HIDDEN MACHINE - 03. Surf (Jarvis9999)
# Processing Anti Hero 2, HIDDEN MACHINE - 04. Strength (Jarvis9999)
# Processing Anti Hero 2, HIDDEN MACHINE - 05. Flash (Jarvis9999)
# Processing Anti Hero 2, HIDDEN MACHINE - 06. Rock Smash (Jarvis9999)
# Processing Anti Hero 2, HIDDEN MACHINE - 07. Waterfall (Jarvis9999)
# Processing Anti Hero 2, HIDDEN MACHINE - 08. Dive (feat. ichika) (Jarvis9999)
# Processing Anti Hero 2, HIDDEN MACHINE - Unlimited Solo Medley (Jarvis9999, CyclopsDragon)
# Processing Anti Hero 2, Hino Isuka - Mechanical Syndrome (Paturages)
# Processing Anti Hero 2, Hiromi - Hiromi Solo Medley (Chemfinal)
# Processing Anti Hero 2, Hiromi's Sonicbloom - Time Out (Live) (GuitarZero132)
# Processing Anti Hero 2, HORSE the band - A Million Exploding Suns (Chezy)
# Processing Anti Hero 2, i built the sky - Radiatus (feat. Stephen Taranto) (Dillski)
# Processing Anti Hero 2, ichika - I (feat. Enon Kawatani) (XEntombmentX)
# Processing Anti Hero 2, Incubus - Anna Molly (Jaded)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Incubus - Anna Molly (Jaded)\notes.chart is not in .chart format
# Processing Anti Hero 2, Interloper - The Conjuration (feat. Lucas Mann) (Dillski)
# Processing Anti Hero 2, Into Eternity - 01. Novus Inceptum Severe Emotional Distress (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 01. Novus Inceptum Severe Emotional Distress (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Into Eternity - 03. Nothing (feat. Collin Craig) (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 03. Nothing (feat. Collin Craig) (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Into Eternity - 04. Timeless Winter (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 04. Timeless Winter (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Into Eternity - 05. Out (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 05. Out (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Into Eternity - 06. A Past Beyond Memory (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 06. A Past Beyond Memory (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Into Eternity - 07. Surrounded by Night (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 07. Surrounded by Night (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Into Eternity - 08. Eternal (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 08. Eternal (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Into Eternity - 09. Pain Through Breathing (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 09. Pain Through Breathing (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Into Eternity - 10. Suspension of Disbelief (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 10. Suspension of Disbelief (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Into Eternity - 11. Paralyzed (Sygenysis)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - 11. Paralyzed (Sygenysis)\notes.chart is not in .chart format
# Processing Anti Hero 2, Into Eternity - The Scattering of Ashes Solo Medley (Sygenysis, CyclopsDragon)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Into Eternity - The Scattering of Ashes Solo Medley (Sygenysis, CyclopsDragon)\notes.chart is not in .chart format
# Processing Anti Hero 2, Jaco Pastorius - Donna Lee (Smoochums)
# Processing Anti Hero 2, James LaBrie - One More Time (Big Whoop Magazine)
# Processing Anti Hero 2, Jane's Addiction - Ocean Size (xX760Xx)
# Processing Anti Hero 2, Jason Becker - Eleven Blue Egyptians (xX760Xx)
# Processing Anti Hero 2, Jeff Loomis - Tragedy and Harmony (feat. Christine Rhoades) (Supahfast198)
# Processing Anti Hero 2, Joe Satriani - If I Could Fly (GuitarZero132)
# Processing Anti Hero 2, John Pizzarelli Trio - After You've Gone (Live) (Chemfinal)
# Processing Anti Hero 2, Josh Mancell - Crash Bandicoot 2 Special Stage Medley (ThundahK)
# Processing Anti Hero 2, Judas Priest - All Guns Blazing (oRizho)
# Processing Anti Hero 2, Junior Senior - Move Your Feet (Jaded)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Junior Senior - Move Your Feet (Jaded)\notes.chart is not in .chart format
# Processing Anti Hero 2, Kairiki Bear - Inaiinai Izonshou (feat. GUMI & Kagamine Rin) (CyclopsDragon)
# Processing Anti Hero 2, Kendrick Lamar - i (Raspberriel)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Kendrick Lamar - i (Raspberriel)\notes.chart is not in .chart format
# Processing Anti Hero 2, Kero Kero Bonito - If I'd Known (Chezy)
# Processing Anti Hero 2, Kiko Loureiro - Gray Stone Gateway (Arctan)
# Processing Anti Hero 2, Killswitch Engage - Still Beats Your Name (XEntombmentX)
# Processing Anti Hero 2, KMNZ - Augmentation (feat. Moe Shop) (Paturages)
# Processing Anti Hero 2, Knocked Loose - Mistakes Like Fractures (Chezy)
# Processing Anti Hero 2, Korpiklaani - Vodka (BurpLeTurtle)
# Processing Anti Hero 2, La Caution - Thé à la Menthe (Paturages)
# Processing Anti Hero 2, Lahmia - The Tunnel (ThundahK)
# Processing Anti Hero 2, Last Dinosaurs - Zoom (Riddo)
# Processing Anti Hero 2, Lemon Demon - BRODYQUEST (JoeyD)
# Processing Anti Hero 2, Linkin Park - Faint (xX760Xx)
# Processing Anti Hero 2, Lizzo - Tempo (feat. Missy Elliot) (Jaded)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Lizzo - Tempo (feat. Missy Elliot) (Jaded)\notes.chart is not in .chart format
# Processing Anti Hero 2, Lost Society - Bitch, Out' My Way (Miscellany)
# Processing Anti Hero 2, Lost Society - No Absolution (Miscellany)
# Processing Anti Hero 2, Louis Cole - Doing the Things (JoeyD)
# Processing Anti Hero 2, Lydian Collective - Thirty One (Paturages)
# Processing Anti Hero 2, M2U - Quo Vadis (Paturages)
# Processing Anti Hero 2, Magnus Opus - Magnum Opus Solo Medley (Supahfast198)
# Processing Anti Hero 2, Marc Rizzo - Isosceles (xX760Xx)
# Processing Anti Hero 2, Marc-André Hamelin - Circus Galop (Arctan)
# Processing Anti Hero 2, Mastodon - Oblivion (XEntombmentX)
# Processing Anti Hero 2, Matt Land - Pamela (Siavash)
# The chart at X:\Training Data\Unprocessed\Anti Hero 2\Matt Land - Pamela (Siavash)\notes.chart is not in .chart format
# Processing Anti Hero 2, Maxo - Plushlined (Paturages)
# Processing Anti Hero 2, Megadeth - 01. Wake Up Dead (xX760Xx)
# Processing Anti Hero 2, Megadeth - 02. The Conjuring (xX760Xx)
# Processing Anti Hero 2, Megadeth - 03. Peace Sells (xX760X)
# Processing Anti Hero 2, Megadeth - 04. Devils Island (xX760Xx)
# Processing Anti Hero 2, Megadeth - 05. Good Mourning Black Friday (xX760Xx)
# Processing Anti Hero 2, Megadeth - 06. Bad Omen (xX760Xx)
# Processing Anti Hero 2, Megadeth - 07. I Ain't Superstitious (Willie Dixon cover) (xX760Xx)
# Processing Anti Hero 2, Megadeth - 08. My Last Words (xX760Xx)
# Processing Anti Hero 2, Megadeth - Peace Sells Solo Medley... but Who's Buying (xX760Xx)
# Processing Anti Hero 2, Megahammer - The Deal Is Sealed (feat. Flash Arnold) (Supahfast198)
# Processing Anti Hero 2, Mekong Delta - Mekong Delta Solo Medley (Sygenysis)
# Processing Anti Hero 2, Mike Orlando - Full Speed X (Chemfinal)
# Processing Anti Hero 2, Mike Orlando - Mike Orlando Solo Medley 2 - The Empire Mikes Back (Chemfinal, CyclopsDragon, xX760Xx)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-33-1d64d8a3d521> in <module>
#      41     # Parse through dense_notes, extracting information
#      42     for x in dense_notes:
# ---> 43         dense_notes_agg.extend(dense_notes)
#      44         modifier.append(modifier_dict[x])
#      45         held.append(hold_dict[x])
#
# MemoryError:

# %% [markdown]
# ### Be careful running this next one, it takes a looong time

# %%
plt.hist(dense_notes, bins = len(np.unique(dense_notes)));
plt.title('Distribution of One Hot Notes')

plt.figure()
plt.hist(modifier)
plt.title('Distribution of \'Tapped\' vs \'Forced\' vs \'Regular\'')

plt.figure()
plt.hist(held)
plt.title('Distribution of \'Held\' vs \'Released\'')
