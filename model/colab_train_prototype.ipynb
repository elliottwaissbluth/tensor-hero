# %%
import sys
from pathlib import Path
import os
sys.path.insert(1, str(Path.cwd().parent))
from tensor_hero.model import ColabLazyDataset
import torch

dl_params = {
            'batch_size' : 12,
            'shuffle' : True,
            'num_workers' : 0,
            'drop_last' : True
        }

train_path = Path(r'X:\Training Data\training_ready\train')
val_path = Path(r'X:\Training Data\training_ready\val')

# Define data loaders
train_data = ColabLazyDataset(train_path, max_src_len=500, max_trg_len=500, pad_idx=434)
train_loader = torch.utils.data.DataLoader(train_data, **dl_params)

for batch_idx, batch in enumerate(train_loader):
    print(f'batch idx: {batch_idx} | shape: {batch}')
    break
# Out:
# 0 datapoints removed due to exceeding maximum length
# batch idx: 0 | shape: [tensor([[[0.8027, 0.8076, 0.8081,  ..., 0.0000, 0.0000, 0.0000],
#          [0.8384, 0.8433, 0.8442,  ..., 0.0000, 0.0000, 0.0000],
#          [0.5483, 0.4629, 0.5229,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.2483, 0.2859, 0.3110,  ..., 0.0000, 0.0000, 0.0000],
#          [0.2842, 0.3218, 0.3469,  ..., 0.0000, 0.0000, 0.0000],
#          [0.3040, 0.3462, 0.3652,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.3782, 0.2404, 0.4141,  ..., 0.0000, 0.0000, 0.0000],
#          [0.4141, 0.2764, 0.4500,  ..., 0.0000, 0.0000, 0.0000],
#          [0.5142, 0.5356, 0.5361,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         ...,
#
#         [[0.2441, 0.2786, 0.3010,  ..., 0.0000, 0.0000, 0.0000],
#          [0.2800, 0.3145, 0.3369,  ..., 0.0000, 0.0000, 0.0000],
#          [0.3101, 0.2444, 0.2515,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.3337, 0.4275, 0.3599,  ..., 0.0000, 0.0000, 0.0000],
#          [0.3699, 0.4636, 0.3958,  ..., 0.0000, 0.0000, 0.0000],
#          [0.4395, 0.4958, 0.5498,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.1376, 0.1559, 0.2864,  ..., 0.0000, 0.0000, 0.0000],
#          [0.1735, 0.1919, 0.3225,  ..., 0.0000, 0.0000, 0.0000],
#          [0.3013, 0.2959, 0.3313,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]]), tensor([[432,  32,   0,  ..., 434, 434, 434],
#         [432, 433, 434,  ..., 434, 434, 434],
#         [432,  37,   2,  ..., 434, 434, 434],
#         ...,
#         [432,  34,   3,  ..., 434, 434, 434],
#         [432,  36,   4,  ..., 434, 434, 434],
#         [432, 146,   1,  ..., 434, 434, 434]])]

# %%
song_paths = [train_path / x for x in os.listdir(train_path)]
notes_dirs = [x / 'notes' for x in song_paths]
specs_dirs = [x / 'spectrograms' for x in song_paths]

specs_lists = []
for dir_ in specs_dirs:
    for specs_dir, _, specs in os.walk(dir_):
        if not specs:
            continue
        specs_lists.append([Path(specs_dir) / spec for spec in specs])
    # print(f'x: {x}\ny: {y}\nz: {z}\n\n')
def __note_dirs_from_spec_dirs(spec_file):
    '''
    Finds the note files corresponding to the spectrogram in spec_dir
    Helper function for ColabLazyDataset __init__()

    ~~~~ ARGUMENTS ~~~~
    - spec_file (Path): 
        - single path to a spectrogram in colab transformer training data
        - assumes file structure defined in tensor_hero/preprocessing/data.py
            -> preprocess_transformer_data() w/ COLAB=True
    
    ~~~~ RETURNS ~~~~
    Path: Path to notes array corresponding to spec in spec_file
    '''
    return Path(str(spec_file).replace('spectrograms', 'notes'))
    
specs_lists = [spec for spec_list in specs_lists for spec in spec_list]  # Flatten
notes_lists = [__note_dirs_from_spec_dirs(x) for x in specs_lists]
print(specs_lists)
# print(notes_lists[-10:])

len(specs_lists)
# Out:
# [WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/0.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/1.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/10.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/11.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/12.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/13.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/14.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/15.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/16.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/17.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/18.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/19.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/2.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/20.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/21.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/22.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/23.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/24.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/25.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/26.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/27.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/28.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/29.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/3.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/30.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/31.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/32.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/33.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/34.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/35.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/36.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/37.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/38.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/39.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/4.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/5.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/6.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/7.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/8.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/0/9.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/1/40.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/1/41.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/1/42.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/1/43.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/1/44.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/1/45.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/1/46.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/1/47.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/1/48.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spectrograms/1/49.npy'), WindowsPath('X:/Training Data/training_ready/train/11/spect ...
# 2008
